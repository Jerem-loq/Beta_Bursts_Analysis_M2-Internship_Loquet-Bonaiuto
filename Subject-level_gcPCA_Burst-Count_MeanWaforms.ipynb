# %%
import glob
import os.path as op
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.linear_model import LogisticRegression as LOR
from sklearn.model_selection import KFold
from generalized_contrastive_PCA import gcPCA
from scipy.stats import median_abs_deviation as MAD

plt.rcParams.update({
    "font.family": "serif",
    "mathtext.fontset": "cm",
})

# %% [markdown]
# ## Define Helpers and Functions

# %%
def reject_outliers(X, m=3, scaling=False):
    """
    Adapted from https://medium.com/@saraswatp/exploring-data-anomalies-rejecting-outliers-with-python-660b1ed6bca6
    Returns a boolean mask where True = 'Keep' and False = 'Outlier'.
    """
    median = np.median(X, axis=0)
    # mad = MAD(X, axis=0, scale='normal')

    if scaling:
        mad = np.median(np.abs(X - median), axis=0) * 1.4826
    else:
        mad = np.median(np.abs(X - median), axis=0)
    
    upper_bound = median + m * mad
    lower_bound = median - m * mad

    mask = (X >= lower_bound) & (X <= upper_bound)

    return mask


def reject_outliers_by_subject_channel(burst_dict, value_key='peak_amp_base', m=3, scaling=False):
    """Compute outlier mask separately within each subject x chennel group.

    Args:
        burst_dict (dictionary): Burst dictionary containing at least:
            - 'subject'
            - 'channel'
            - value_key
        
        value_key (str, optional): Name of the feature on which to reject outliers. Defaults to 'peak_amp_base'.
        m (float, optional): Number of MADs from the median used as the cutoff. Defaults to 3.
        scaling (bool, optional): If True, scale MAD by 1.4826. Defaults to False.
    
    Returns:
        group_mask: ndarray of bool, shape (n_bursts,). Global mask with True = keep, False = outlier.
    """

    values = np.asarray(burst_dict[value_key])
    subjects_arr = np.asarray(burst_dict['subject'])
    channels_arr = np.asarray(burst_dict['channel'])

    n = len(values)
    if not (len(subjects_arr) == n and len(channels_arr) == n):
        raise ValueError(f"'subject', 'channel', and '{value_key}' must have the same length." )
    
    group_mask = np.ones(n, dtype=bool)
    unique_subjects = np.unique(subjects_arr)

    for sub in unique_subjects:
        sub_idx = subjects_arr == sub
        sub_channels = np.unique(channels_arr[sub_idx])

        for ch in sub_channels:
            idx = sub_idx & (channels_arr == ch)

            # Reject within this subject x channel subset
            local_mask = reject_outliers(values[idx], m=m, scaling=scaling)

            # Write local decisions back into full-length mask
            group_mask[idx] = local_mask

    return group_mask

# %%
def scaler_fit(X):
    median = np.median(X, axis=0)
    mad = MAD(X, axis=0, scale='normal')
    return median, mad


def scaler_transform(X, median, mad):
    return (X - median) / mad

# %% [markdown]
# ## Data loading

# %% [markdown]
# ### Channel labels

# %%
ch_labels = ['STN_L1', 'STN_L2', 'STN_L3', 'STN_L4', 'STN_R1', 'STN_R2', 'STN_R3', 'STN_R4', 'F3', 'Fz', 'F4', 'C3', 'C4', 'Cz']

# %% [markdown]
# ### Subject labels

# %%
data_dir = '../../data/preprocessed_data/'
out_path = '../../data/derivatives/'
data_files = glob.glob(op.join(data_dir, 'dataClean_step1_*_MED_ON.mat'))
subjects = sorted([x.split('/')[-1].split('_')[3] for x in data_files])
print(subjects)
# Out:
# ['s02', 's04', 's05', 's06', 's07', 's08', 's10', 's15', 's16', 's17', 's18']

# %% [markdown]
# ### Aggregating burst features of the STN and of motor cortex (C3,C4) across all subjects

# %%
all_bursts={
    'subject': [],
    'med': [],
    'channel': [],
    'trial': [],
    'waveform': np.zeros((0,132)),
    'waveform_times': [],
    'peak_freq': [],
    'peak_amp_iter': [],
    'peak_amp_base': [],
    'peak_time': [],
    'peak_adjustment': [],
    'fwhm_freq': [],
    'fwhm_time': [],
    'polarity': [],
}

for subject in subjects:
    fname = op.join(out_path, 'beta', f'bursts_{subject}.pickle')
    if op.exists(fname):
        print(subject)
        with open(fname,'rb') as file:  # rb = read binary
            bursts = pickle.load(file)
        
        # stn_c_bursts = boolean containing True for STNs and C3, C4 and False for every other channels
        stn_c_bursts = np.char.startswith(bursts['channel'].astype(str), 'STN') | (bursts['channel']=='C3') | (bursts['channel']=='C4')
        
        # Loads the data from bursts to all_bursts
        for key in bursts.keys():
            if key=='waveform_times':
                all_bursts[key] = bursts[key]

            elif key=='waveform':
                all_bursts[key] = np.vstack([all_bursts[key], bursts[key][stn_c_bursts, :]])

            else:
                all_bursts[key] = np.hstack([all_bursts[key], bursts[key][stn_c_bursts]])
# Out:
# s02
# s04
# s05
# s06
# s07
# s08
# s10
# s15
# s16
# s17
# s18

# %% [markdown]
# ## Perform light pre-processing
# * Redefine the trial indices ensuring they're not overlapping between ON and OFF medication - subject-level based
# * Convert burst time to ms
# * Reject outliers based on their peak amplitude

# %%
for subject in subjects:
    subj_idx = (all_bursts['subject']==subject)
    off_med_trials = np.unique(all_bursts['trial'][subj_idx & (all_bursts['med']=='OFF')])
    max_off_trial = np.max(off_med_trials)
    on_med_idx = subj_idx & (all_bursts['med']=='ON')
    all_bursts['trial'][on_med_idx] = all_bursts['trial'][on_med_idx] + max_off_trial + 1

# %%
burst_times = all_bursts['waveform_times'] * 1000

# %%
outlier_mask = reject_outliers_by_subject_channel(
    all_bursts,
    value_key='peak_amp_base',
    m=3,
    scaling=False
    )

len_mask = len(outlier_mask)

correct_bursts = {
    key: (value[outlier_mask] if len(value) == len_mask else value)
    for key, value in all_bursts.items()
    }

# print(f"Original trials: {len(all_bursts['peak_amp_base'])}")
# print(f"Corrected trials: {len(correct_bursts['peak_amp_base'])}")
# print(f"Removed trials: {len(all_bursts['peak_amp_base']) - len(correct_bursts['peak_amp_base'])}")

# %% [markdown]
# ### Select bursts corresponding to C3/C4 and all STN contacts

# %%
c_idx = (correct_bursts['channel']=='C3') | (correct_bursts['channel']=='C4')
stn_idx = [ch.startswith('STN') for ch in correct_bursts['channel']]

# %%
on_idx = (correct_bursts['med']=='ON')
off_idx = (correct_bursts['med']=='OFF')
on_c_idx = c_idx & on_idx
off_c_idx = c_idx & off_idx
on_stn_idx = stn_idx & on_idx
off_stn_idx = stn_idx & off_idx

# %%
"""
```scaling_method``` accepts: 
    - 'MAD-based',
    - 'Robust',
    - 'Standard'
"""
scaling_method = 'MAD-based'

area = c_idx
scaled_waveforms = np.zeros_like(correct_bursts['waveform'])
for subject in np.unique(correct_bursts['subject']):
    subj_idx = (correct_bursts['subject'] == subject)

    if scaling_method == 'Robust':
        """Perform a modified z-score based on median and IQR"""
        scaler = RobustScaler().fit(correct_bursts['waveform'][subj_idx & area])                # .fit() returns the median and IQR values
        scaled_waveforms[subj_idx, :] = scaler.transform(correct_bursts['waveform'][subj_idx])  # .transform() does the maths.

    elif scaling_method == 'Standard':
        """Perform a z-score based on mean and STD"""
        scaler = StandardScaler().fit(correct_bursts['waveform'][subj_idx & area])              # .fit() returns the mean and STD values
        scaled_waveforms[subj_idx, :] = scaler.transform(correct_bursts['waveform'][subj_idx])  # .transform() does the maths.

    elif scaling_method == 'MAD-based':
        """Perfom a modified z-score based on median and MAD"""
        median, mad = scaler_fit(correct_bursts['waveform'][subj_idx & area])                   # Scaler based on MAD
        scaled_waveforms[subj_idx, :] = scaler_transform(correct_bursts['waveform'][subj_idx], median, mad)

    else:
        raise AttributeError("Wrong scaling method. Valide options are ['MAD-based', 'Robust', 'Standard'].")

# %% [markdown]
# ## Train a logistic regression on the beta burst waveform for sensorimotor cortex (C3,C4) Vs STN that undergo a rPCA

# %%
# Subject-level cross-validation: split subjects into train/test groups

n_splits = 10           # Number of folds for cross-validation
n_bins = 4              # Number of bins to use for each gcPC
cols = [0, 1, -2, -1]   # List of gcPC columns to consider

subjects_score = []
for subject in subjects:
    subj_idx = (correct_bursts['subject']==subject) & area
    trials = np.unique(correct_bursts['trial'][subj_idx])

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=6)
    
    fold_score = []
    for fold_idx, (train_index, test_index) in enumerate(kf.split(trials)):
        train_bursts_idx = np.isin(correct_bursts['trial'], trials[train_index]) & subj_idx
        train_bursts_on_idx = train_bursts_idx & (correct_bursts['med']=='ON')
        train_bursts_off_idx = train_bursts_idx & (correct_bursts['med']=='OFF')
            
        # GCPCA model trained only on test set bursts of the current subject
        gcpca_model = gcPCA(method='v4', normalize_flag=False)                                                      # gcPCA model creation
        gcpca_model.fit(scaled_waveforms[train_bursts_off_idx, :], scaled_waveforms[train_bursts_on_idx, :])        # gcPCA application on OFF/ON cortex
        
        # Project all bursts of the current subject into PC space using the trained model
        all_scores = scaled_waveforms@gcpca_model.loadings_
        
        X = []
        y = []
        pc_bin_lims = np.zeros((len(cols), n_bins + 1))
        # Build trial-level feature matrix X and matching label vector y
        for trial in trials:
            # For each trial, count how many bursts fall into each bin for the current gcPC
            burst_idx = subj_idx & (correct_bursts["trial"]==trial)
            label = np.unique(correct_bursts["med"][burst_idx])[0]

            row = []
            for i, col in enumerate(cols):
                # Compute percentile edges for each gcPC of interest across all bursts 
                pc_bin_lims[i, :] = np.percentile(all_scores[train_bursts_idx, col], np.linspace(0, 100, n_bins + 1))

                for idx in range(len(pc_bin_lims[i, :]) - 1):
                    # Count bursts whose gcPC score falls within the current percentile bin
                    count = len(np.where((all_scores[burst_idx, cols[i]] >= pc_bin_lims[i, idx]) &
                                        (all_scores[burst_idx, cols[i]] < pc_bin_lims[i, idx+1]))[0])
                    row.append(count)

            X.append(row)
            y.append(0 if label=='OFF' else 1)

        X = np.array(X)
        y = np.array(y)

        model = LOR(max_iter=10_000)
        model = model.fit(X[train_index, :], y[train_index])
        y_pred = model.predict(X[test_index, :])

        score = 1 - np.sqrt(np.mean((y[test_index] - y_pred) ** 2))
        print(f'Subject {subject} fold {fold_idx}: Score = {score:.3f}')
        fold_score.append(score)

    print(f'Subject {subject}: Mean Score = {np.mean(fold_score):.3f} ± {np.std(fold_score):.3f}')
    subjects_score.append(np.mean(fold_score))

print(f'Overall Mean Score across subjects: {np.mean(subjects_score):.3f} ± {np.std(subjects_score):.3f}')
# Out:
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 0: Score = 0.134
# Subject s02 fold 1: Score = 0.293
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 2: Score = 0.293
# Subject s02 fold 3: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 4: Score = 0.500
# Subject s02 fold 5: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 6: Score = 0.134
# Subject s02 fold 7: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 8: Score = 1.000
# Subject s02 fold 9: Score = 1.000
# Subject s02: Mean Score = 0.535 ± 0.330
# Subject s04 fold 0: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 1: Score = 1.000
# Subject s04 fold 2: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 3: Score = 1.000
# Subject s04 fold 4: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 5: Score = 1.000
# Subject s04 fold 6: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 7: Score = 1.000
# Subject s04 fold 8: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 9: Score = 1.000
# Subject s04: Mean Score = 1.000 ± 0.000
# Subject s05 fold 0: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 1: Score = 0.134
# Subject s05 fold 2: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 3: Score = 0.293
# Subject s05 fold 4: Score = 0.293
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 5: Score = 0.500
# Subject s05 fold 6: Score = 0.293
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 7: Score = 0.423
# Subject s05 fold 8: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 9: Score = 1.000
# Subject s05: Mean Score = 0.494 ± 0.277
# Subject s06 fold 0: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 1: Score = 0.134
# Subject s06 fold 2: Score = 0.293
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 3: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 4: Score = 0.500
# Subject s06 fold 5: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 6: Score = 0.134
# Subject s06 fold 7: Score = 0.293
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 8: Score = 0.500
# Subject s06 fold 9: Score = 0.134
# Subject s06: Mean Score = 0.449 ± 0.310
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 0: Score = 0.500
# Subject s07 fold 1: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 2: Score = 1.000
# Subject s07 fold 3: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 4: Score = 0.293
# Subject s07 fold 5: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 6: Score = 0.134
# Subject s07 fold 7: Score = 0.423
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 8: Score = 0.184
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 9: Score = 0.000
# Subject s07: Mean Score = 0.453 ± 0.318
# Subject s08 fold 0: Score = 0.293
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 1: Score = 0.500
# Subject s08 fold 2: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 3: Score = 0.293
# Subject s08 fold 4: Score = 0.134
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 5: Score = 0.500
# Subject s08 fold 6: Score = 0.293
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 7: Score = 0.293
# Subject s08 fold 8: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 9: Score = 0.423
# Subject s08: Mean Score = 0.473 ± 0.284
# Subject s10 fold 0: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 1: Score = 0.293
# Subject s10 fold 2: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 3: Score = 0.500
# Subject s10 fold 4: Score = 0.293
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 5: Score = 1.000
# Subject s10 fold 6: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 7: Score = 0.134
# Subject s10 fold 8: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 9: Score = 0.423
# Subject s10: Mean Score = 0.464 ± 0.215
# Subject s15 fold 0: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 1: Score = 1.000
# Subject s15 fold 2: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 3: Score = 1.000
# Subject s15 fold 4: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 5: Score = 1.000
# Subject s15 fold 6: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 7: Score = 0.500
# Subject s15 fold 8: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 9: Score = 1.000
# Subject s15: Mean Score = 0.900 ± 0.200
# Subject s16 fold 0: Score = 0.368
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 1: Score = 0.500
# Subject s16 fold 2: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 3: Score = 1.000
# Subject s16 fold 4: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 5: Score = 1.000
# Subject s16 fold 6: Score = 0.500
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 7: Score = 1.000
# Subject s16 fold 8: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 9: Score = 1.000
# Subject s16: Mean Score = 0.737 ± 0.266
# Subject s17 fold 0: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 1: Score = 1.000
# Subject s17 fold 2: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 3: Score = 1.000
# Subject s17 fold 4: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 5: Score = 1.000
# Subject s17 fold 6: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 7: Score = 1.000
# Subject s17 fold 8: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 9: Score = 1.000
# Subject s17: Mean Score = 1.000 ± 0.000
# Subject s18 fold 0: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 1: Score = 1.000
# Subject s18 fold 2: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 3: Score = 1.000
# Subject s18 fold 4: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 5: Score = 1.000
# Subject s18 fold 6: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 7: Score = 1.000
# Subject s18 fold 8: Score = 1.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 9: Score = 1.000
# Subject s18: Mean Score = 1.000 ± 0.000
# Overall Mean Score across subjects: 0.682 ± 0.235

# %%
# Subject-level cross-validation: split subjects into train/test groups and save scores for different number of bins
# and subject-level model coefficients 

n_splits = 10  # Number of folds for cross-validation
n_bins = 4  # Number of bins to use for each gcPC
cols = [0, 1, -2, -1]  # List of gcPC columns to consider

subjects_coefs = {subject: [] for subject in subjects}  # Dictionary to store coefficients for each subject
subjects_bursts = {subject: [] for subject in subjects}  # Dictionary to store bursts for each subject
subjects_score = []
for subject in subjects:
    subj_idx = (correct_bursts['subject']==subject) & area
    trials = np.unique(correct_bursts['trial'][subj_idx])

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=6)
    
    coef = []
    fold_score = []
    for fold_idx, (train_index, test_index) in enumerate(kf.split(trials)):
        train_bursts_idx = np.isin(correct_bursts['trial'], trials[train_index]) & subj_idx
        train_bursts_on_idx = train_bursts_idx & (correct_bursts['med']=='ON')
        train_bursts_off_idx = train_bursts_idx & (correct_bursts['med']=='OFF')
            
        # GCPCA model trained only on test set bursts of the current subject
        gcpca_model = gcPCA(method='v4', normalize_flag=False)                                # gcPCA model creation
        gcpca_model.fit(scaled_waveforms[train_bursts_off_idx, :], scaled_waveforms[train_bursts_on_idx, :])        # gcPCA application on OFF/ON cortex
    
        # Project all bursts of the current subject into PC space using the trained model
        all_scores = scaled_waveforms@gcpca_model.loadings_
        
        X = []
        y = []
        pc_bin_lims = np.zeros((len(cols), n_bins + 1))

        # Build trial-level feature matrix X and matching label vector y
        for trial in trials:
            # For each trial, count how many bursts fall into each bin for the current gcPC
            burst_idx = subj_idx & (correct_bursts["trial"]==trial)
            label = np.unique(correct_bursts["med"][burst_idx])[0]

            row = []
            for i, col in enumerate(cols):
                # Compute percentile edges for each gcPC of interest across all bursts 
                pc_bin_lims[i, :] = np.percentile(all_scores[train_bursts_idx, col], np.linspace(0, 100, n_bins + 1))

                for idx in range(len(pc_bin_lims[i, :]) - 1):
                    # Count bursts whose gcPC score falls within the current percentile bin
                    count = len(np.where((all_scores[burst_idx, cols[i]] >= pc_bin_lims[i, idx]) &
                                        (all_scores[burst_idx, cols[i]] < pc_bin_lims[i, idx+1]))[0])
                    row.append(count)

            X.append(row)
            y.append(0 if label=='OFF' else 1)

        X = np.array(X)
        y = np.array(y)

        subjects_bursts[subject].append(np.mean(X, axis=0))

        model = LOR(max_iter=10_000)
        model = model.fit(X[train_index, :], y[train_index])
        y_train_pred = model.predict(X[train_index, :])
        y_test_pred = model.predict(X[test_index, :])
        coefs = model.coef_
        coef.append(coefs)

        train_score = np.mean(y[train_index] == y_train_pred)
        test_score = np.mean(y[test_index] == y_test_pred)
        print(f'Subject {subject} fold {fold_idx}: Train Score = {train_score:.3f}, Test Score = {test_score:.3f}, Min = {np.min(y[train_index])}, Max = {np.max(y[train_index])}')
        fold_score.append(test_score)

    print(f'Subject {subject}: Mean Score = {np.mean(fold_score):.3f} ± {np.std(fold_score):.3f}')
    subjects_score.append(np.mean(fold_score))
    subjects_coefs[subject].append(np.mean(coef, axis=0))


print(f'Overall Mean Score across subjects: {np.mean(subjects_score):.3f} ± {np.std(subjects_score):.3f}')
# Out:
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 0: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# Subject s02 fold 1: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 2: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# Subject s02 fold 3: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 4: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s02 fold 5: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 6: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# Subject s02 fold 7: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s02 fold 8: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s02 fold 9: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s02: Mean Score = 0.675 ± 0.275
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 0: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s04 fold 1: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 2: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s04 fold 3: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 4: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s04 fold 5: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 6: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s04 fold 7: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s04 fold 8: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s04 fold 9: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s04: Mean Score = 1.000 ± 0.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 0: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s05 fold 1: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 2: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s05 fold 3: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 4: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# Subject s05 fold 5: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 6: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# Subject s05 fold 7: Train Score = 1.000, Test Score = 0.667, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s05 fold 8: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s05 fold 9: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s05: Mean Score = 0.667 ± 0.224
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 0: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s06 fold 1: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 2: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# Subject s06 fold 3: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 4: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s06 fold 5: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 6: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# Subject s06 fold 7: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s06 fold 8: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s06 fold 9: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# Subject s06: Mean Score = 0.600 ± 0.278
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 0: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s07 fold 1: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 2: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s07 fold 3: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 4: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# Subject s07 fold 5: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 6: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# Subject s07 fold 7: Train Score = 1.000, Test Score = 0.667, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s07 fold 8: Train Score = 1.000, Test Score = 0.333, Min = 0, Max = 1
# Subject s07 fold 9: Train Score = 1.000, Test Score = 0.000, Min = 0, Max = 1
# Subject s07: Mean Score = 0.600 ± 0.309
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 0: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# Subject s08 fold 1: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 2: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s08 fold 3: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 4: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# Subject s08 fold 5: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 6: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# Subject s08 fold 7: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s08 fold 8: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s08 fold 9: Train Score = 1.000, Test Score = 0.667, Min = 0, Max = 1
# Subject s08: Mean Score = 0.642 ± 0.227
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 0: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s10 fold 1: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 2: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s10 fold 3: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 4: Train Score = 1.000, Test Score = 0.500, Min = 0, Max = 1
# Subject s10 fold 5: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 6: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s10 fold 7: Train Score = 1.000, Test Score = 0.250, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s10 fold 8: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s10 fold 9: Train Score = 1.000, Test Score = 0.667, Min = 0, Max = 1
# Subject s10: Mean Score = 0.667 ± 0.194
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 0: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s15 fold 1: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 2: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s15 fold 3: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 4: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s15 fold 5: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 6: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s15 fold 7: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s15 fold 8: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s15 fold 9: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s15: Mean Score = 0.950 ± 0.100
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 0: Train Score = 1.000, Test Score = 0.600, Min = 0, Max = 1
# Subject s16 fold 1: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 2: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s16 fold 3: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 4: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s16 fold 5: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 6: Train Score = 1.000, Test Score = 0.750, Min = 0, Max = 1
# Subject s16 fold 7: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s16 fold 8: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s16 fold 9: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s16: Mean Score = 0.860 ± 0.146
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 0: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s17 fold 1: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 2: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s17 fold 3: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 4: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s17 fold 5: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 6: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s17 fold 7: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s17 fold 8: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s17 fold 9: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s17: Mean Score = 1.000 ± 0.000
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 0: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s18 fold 1: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 2: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s18 fold 3: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 4: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s18 fold 5: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 6: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s18 fold 7: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
# Subject s18 fold 8: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s18 fold 9: Train Score = 1.000, Test Score = 1.000, Min = 0, Max = 1
# Subject s18: Mean Score = 1.000 ± 0.000
# Overall Mean Score across subjects: 0.787 ± 0.165
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +

# %% [markdown]
# ## Plot mean waveforms for each bin of each gcPC, averaged across subjects (excluding or not the last left out)

# %%
n_bins = 3

fig, ax = plt.subplots(len(cols), n_bins, figsize=(30, 15))

# Assign colors to subjects
cmap = plt.cm.get_cmap('tab20', len(subjects))
subject_colors = {sub: cmap(i) for i, sub in enumerate(subjects)}

labels = []
mean_waveforms = []  # for all subjects
for col in cols:
    bin_mean_waveforms = []  # reset for each col
    for bin in range(n_bins):
        sub_mean_waveforms = []  # for each bin
        for sub in subjects:  # [subjects != "s18"]
            sub_bursts_idx = np.isin(correct_bursts['subject'], sub) & area
            pc_bin_lims = np.percentile(all_scores[sub_bursts_idx, col], np.linspace(0, 100, n_bins + 1))
            
            if bin == (n_bins - 1):
                lims = (all_scores[:, col] >= pc_bin_lims[bin])
            else:
                lims = (all_scores[:, col] >= pc_bin_lims[bin]) & (all_scores[:, col] < pc_bin_lims[bin + 1])
            
            idx = (correct_bursts['subject'] == sub) & area & lims
            if np.sum(idx) > 0:  # check if there are bursts
                label = str(sub)
                if label not in labels:
                    labels.append(label)

                mean_sub_waveform = np.mean(correct_bursts['waveform'][idx, :], axis=0)
                ax[col, bin].plot(burst_times, mean_sub_waveform, color=subject_colors[sub], label=label, alpha=0.5)
                ax[col, bin].tick_params(axis='both', which='major', labelsize=20)
                sub_mean_waveforms.append(mean_sub_waveform)
        
        if sub_mean_waveforms:
            label = "Mean"
            if label not in labels:
                labels.append(label)

            overall_mean = np.mean(np.array(sub_mean_waveforms), axis=0)
            ax[col, bin].plot(burst_times, overall_mean, label=label, color='black', alpha=1)
            bin_mean_waveforms.extend(sub_mean_waveforms)

        ax[0, bin].set_title(f'Bin {bin + 1}', fontsize=25)
        ax[len(cols)-1, bin].set_xlabel('Burst time (ms)', fontsize=25)

    if bin_mean_waveforms:
        mean_waveforms.append(np.mean(np.array(bin_mean_waveforms), axis=0))       

    ax[col, 0].set_ylabel(f'gcPC{col}', fontsize=25)

# Adjust subplots to make space for legend
fig.subplots_adjust(right=0.85)
fig.legend(labels=labels, bbox_to_anchor=(0.98, 0.90), title='Subjects', title_fontsize=25, fontsize=25)
fig.suptitle('Mean Burst Waveforms by gcPC Bin - StandardScaling', fontsize=30)
plt.tight_layout(rect=[0, 0, 0.85, 0.97])
# Out:
# C:\Users\Loquet Jeremie\AppData\Local\Temp\ipykernel_12304\796107456.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab20', len(subjects))

# %%
area = stn_idx

# Scale waveforms within subject such as (X - median)/IQR 
scaled_waveforms = np.zeros_like(correct_bursts['waveform'])

n_q = 4
col_r = plt.cm.cool(np.linspace(0, 1, num=n_q))
rev_col_r = col_r[::-1]
step = 100 / n_q

gcPC = [0, 1, -2, -1]

fig, ax = plt.subplots(len(gcPC), n_q, figsize=(4*n_q, len(gcPC)*4), constrained_layout=True)

labels = []
q_waveforms = []
subjects_scores = []
for subject in np.unique(correct_bursts['subject']):
    subj_idx = (correct_bursts['subject'] == subject)
    # scaler = RobustScaler().fit(correct_bursts['waveform'][subj_idx & area])          # .fit() returns the median and IQR values
    # scaler = StandardScaler().fit(correct_bursts['waveform'][subj_idx & area])        # .fit() returns the mean and std values
    median, mad = scaler_fit(correct_bursts['waveform'][subj_idx & area])               # .fit() returns the median and MAD values
    subj_med = correct_bursts['med'][subj_idx & area]
    subj_bursts = correct_bursts['waveform'][subj_idx & area,:]
    subj_on_idx = (subj_med=='ON')
    subj_off_idx = (subj_med=='OFF')
    # subj_scaled_waveforms = scaler.transform(subj_bursts)
    subj_scaled_waveforms = scaler_transform(subj_bursts, median, mad)

    sub_gcpca_model = gcPCA(method='v4', normalize_flag=False)
    sub_gcpca_model.fit(subj_scaled_waveforms[subj_on_idx,:], subj_scaled_waveforms[subj_off_idx,:])
    subj_scores = subj_scaled_waveforms @ sub_gcpca_model.loadings_
    subjects_scores.append(subj_scores)

    for q in range(n_q):
        for col in gcPC:
            q_bins = np.percentile(subj_scores[:, col], np.arange(0, 100+step, step))
            print(" bins:", q_bins)

            if q==(n_q-1):
                lims = (subj_scores[:, col] >= q_bins[q])
            else:
                lims = (subj_scores[:, col] >= q_bins[q]) & (subj_scores[:, col] < q_bins[q+1])
            print(f'  subject: {subject}, gcPC{col}, q={q}, n_bursts={len(np.where(lims)[0])}')
            q_waveform = np.mean(subj_scaled_waveforms[lims, :], axis=0)
            q_waveforms.append(q_waveform)

            if len(np.where(lims)[0]) > 0:
                label = f'{subject}'
            else:
                label = None

            if label not in labels:
                labels.append(label)

            ax[col, q].plot(burst_times, q_waveform, label=label)
            ax[len(gcPC)-1, q].set_xlabel('Burst time (ms)')
            ax[col, 0].set_ylabel(f'gcPC{col}\nAmplitude (µV)')
            ax[0, q].set_title(f"T{q+1}")
            ax[col, q].set_box_aspect(1)

            if subject == np.unique(correct_bursts['subject'])[-1]:
                ax[col, q].plot(burst_times, np.mean(q_waveforms, axis=0), color='black', linestyle='--', label='Average')

                if 'Average' not in labels:
                    labels.append('Average')

fig.suptitle('Subject-level - Burst waveforms across gcPCs and quantiles', fontsize=16)
fig.legend(labels=labels, bbox_to_anchor=(1.05, 1), loc='upper left')
# Out:
# c:\Users\Loquet Jeremie\Documents\Python_Project\gcPCA\.venv\Lib\site-packages\generalized_contrastive_PCA\contrastive_methods.py:176: UserWarning: Denominator is ill-conditioned, fixing it. Be aware that gcPCA values will beslightly smaller
#   warnings.warn('Denominator is ill-conditioned, fixing it. ' +
#  bins: [-9.93674556e-05 -1.13923760e-05  1.28260343e-06  1.31850534e-05
#   1.80433952e-04]
#   subject: s02, gcPC0, q=0, n_bursts=474
#  bins: [-1.88244114e-04 -2.40754085e-05 -6.72590833e-06  8.47882930e-06
#   1.34464239e-04]
#   subject: s02, gcPC1, q=0, n_bursts=474
#  bins: [-1.49249315e-04 -3.68239661e-05 -1.48869329e-06  2.94459834e-05
#   1.32607371e-04]
#   subject: s02, gcPC-2, q=0, n_bursts=474
#  bins: [-1.01979418e-04 -2.45496880e-05  1.60494837e-06  2.31117908e-05
#   8.28636485e-05]
#   subject: s02, gcPC-1, q=0, n_bursts=474
#  bins: [-9.93674556e-05 -1.13923760e-05  1.28260343e-06  1.31850534e-05
#   1.80433952e-04]
#   subject: s02, gcPC0, q=1, n_bursts=474
#  bins: [-1.88244114e-04 -2.40754085e-05 -6.72590833e-06  8.47882930e-06
#   1.34464239e-04]
#   subject: s02, gcPC1, q=1, n_bursts=474
#  bins: [-1.49249315e-04 -3.68239661e-05 -1.48869329e-06  2.94459834e-05
#   1.32607371e-04]
#   subject: s02, gcPC-2, q=1, n_bursts=474
#  bins: [-1.01979418e-04 -2.45496880e-05  1.60494837e-06  2.31117908e-05
#   8.28636485e-05]
#   subject: s02, gcPC-1, q=1, n_bursts=474
#  bins: [-9.93674556e-05 -1.13923760e-05  1.28260343e-06  1.31850534e-05
#   1.80433952e-04]
#   subject: s02, gcPC0, q=2, n_bursts=474
#  bins: [-1.88244114e-04 -2.40754085e-05 -6.72590833e-06  8.47882930e-06
#   1.34464239e-04]
#   subject: s02, gcPC1, q=2, n_bursts=474
#  bins: [-1.49249315e-04 -3.68239661e-05 -1.48869329e-06  2.94459834e-05
#   1.32607371e-04]
#   subject: s02, gcPC-2, q=2, n_bursts=474
#  bins: [-1.01979418e-04 -2.45496880e-05  1.60494837e-06  2.31117908e-05
#   8.28636485e-05]
#   subject: s02, gcPC-1, q=2, n_bursts=474
#  bins: [-9.93674556e-05 -1.13923760e-05  1.28260343e-06  1.31850534e-05
#   1.80433952e-04]
#   subject: s02, gcPC0, q=3, n_bursts=475
#  bins: [-1.88244114e-04 -2.40754085e-05 -6.72590833e-06  8.47882930e-06
#   1.34464239e-04]
#   subject: s02, gcPC1, q=3, n_bursts=475
#  bins: [-1.49249315e-04 -3.68239661e-05 -1.48869329e-06  2.94459834e-05
#   1.32607371e-04]
#   subject: s02, gcPC-2, q=3, n_bursts=475
#  bins: [-1.01979418e-04 -2.45496880e-05  1.60494837e-06  2.31117908e-05
#   8.28636485e-05]
#   subject: s02, gcPC-1, q=3, n_bursts=475
#  bins: [-7.10666902e-05 -5.00386088e-06  1.88288514e-06  8.10410821e-06
#   8.33386679e-05]
#   subject: s04, gcPC0, q=0, n_bursts=515
#  bins: [-7.53873664e-05 -4.01707632e-06  9.92705887e-07  5.98423273e-06
#   5.88750887e-05]
#   subject: s04, gcPC1, q=0, n_bursts=515
#  bins: [-2.84841494e-03 -7.60819579e-05  1.03660114e-06  1.69958449e-04
#   2.88498120e-03]
#   subject: s04, gcPC-2, q=0, n_bursts=515
#  bins: [-1.56141441e-03 -1.07057243e-04 -1.02287841e-06  3.16166034e-05
#   1.57845373e-03]
#   subject: s04, gcPC-1, q=0, n_bursts=515
#  bins: [-7.10666902e-05 -5.00386088e-06  1.88288514e-06  8.10410821e-06
#   8.33386679e-05]
#   subject: s04, gcPC0, q=1, n_bursts=514
#  bins: [-7.53873664e-05 -4.01707632e-06  9.92705887e-07  5.98423273e-06
#   5.88750887e-05]
#   subject: s04, gcPC1, q=1, n_bursts=514
#  bins: [-2.84841494e-03 -7.60819579e-05  1.03660114e-06  1.69958449e-04
#   2.88498120e-03]
#   subject: s04, gcPC-2, q=1, n_bursts=514
#  bins: [-1.56141441e-03 -1.07057243e-04 -1.02287841e-06  3.16166034e-05
#   1.57845373e-03]
#   subject: s04, gcPC-1, q=1, n_bursts=514
#  bins: [-7.10666902e-05 -5.00386088e-06  1.88288514e-06  8.10410821e-06
#   8.33386679e-05]
#   subject: s04, gcPC0, q=2, n_bursts=514
#  bins: [-7.53873664e-05 -4.01707632e-06  9.92705887e-07  5.98423273e-06
#   5.88750887e-05]
#   subject: s04, gcPC1, q=2, n_bursts=514
#  bins: [-2.84841494e-03 -7.60819579e-05  1.03660114e-06  1.69958449e-04
#   2.88498120e-03]
#   subject: s04, gcPC-2, q=2, n_bursts=514
#  bins: [-1.56141441e-03 -1.07057243e-04 -1.02287841e-06  3.16166034e-05
#   1.57845373e-03]
#   subject: s04, gcPC-1, q=2, n_bursts=514
#  bins: [-7.10666902e-05 -5.00386088e-06  1.88288514e-06  8.10410821e-06
#   8.33386679e-05]
#   subject: s04, gcPC0, q=3, n_bursts=515
#  bins: [-7.53873664e-05 -4.01707632e-06  9.92705887e-07  5.98423273e-06
#   5.88750887e-05]
#   subject: s04, gcPC1, q=3, n_bursts=515
#  bins: [-2.84841494e-03 -7.60819579e-05  1.03660114e-06  1.69958449e-04
#   2.88498120e-03]
#   subject: s04, gcPC-2, q=3, n_bursts=515
#  bins: [-1.56141441e-03 -1.07057243e-04 -1.02287841e-06  3.16166034e-05
#   1.57845373e-03]
#   subject: s04, gcPC-1, q=3, n_bursts=515
#  bins: [-1.87459025e-04 -3.37241873e-05 -9.61712460e-06  1.39690146e-05
#   1.31150874e-04]
#   subject: s05, gcPC0, q=0, n_bursts=500
#  bins: [-1.81927567e-04 -2.34465386e-05 -7.45602333e-07  2.25612948e-05
#   1.45563261e-04]
#   subject: s05, gcPC1, q=0, n_bursts=500
#  bins: [-9.37331533e-05 -1.17052934e-05  2.12335152e-06  1.67467400e-05
#   9.60046327e-05]
#   subject: s05, gcPC-2, q=0, n_bursts=500
#  bins: [-7.00321805e-05 -1.23777900e-05 -4.39404030e-07  1.02218846e-05
#   7.50548939e-05]
#   subject: s05, gcPC-1, q=0, n_bursts=500
#  bins: [-1.87459025e-04 -3.37241873e-05 -9.61712460e-06  1.39690146e-05
#   1.31150874e-04]
#   subject: s05, gcPC0, q=1, n_bursts=500
#  bins: [-1.81927567e-04 -2.34465386e-05 -7.45602333e-07  2.25612948e-05
#   1.45563261e-04]
#   subject: s05, gcPC1, q=1, n_bursts=500
#  bins: [-9.37331533e-05 -1.17052934e-05  2.12335152e-06  1.67467400e-05
#   9.60046327e-05]
#   subject: s05, gcPC-2, q=1, n_bursts=500
#  bins: [-7.00321805e-05 -1.23777900e-05 -4.39404030e-07  1.02218846e-05
#   7.50548939e-05]
#   subject: s05, gcPC-1, q=1, n_bursts=500
#  bins: [-1.87459025e-04 -3.37241873e-05 -9.61712460e-06  1.39690146e-05
#   1.31150874e-04]
#   subject: s05, gcPC0, q=2, n_bursts=500
#  bins: [-1.81927567e-04 -2.34465386e-05 -7.45602333e-07  2.25612948e-05
#   1.45563261e-04]
#   subject: s05, gcPC1, q=2, n_bursts=500
#  bins: [-9.37331533e-05 -1.17052934e-05  2.12335152e-06  1.67467400e-05
#   9.60046327e-05]
#   subject: s05, gcPC-2, q=2, n_bursts=500
#  bins: [-7.00321805e-05 -1.23777900e-05 -4.39404030e-07  1.02218846e-05
#   7.50548939e-05]
#   subject: s05, gcPC-1, q=2, n_bursts=500
#  bins: [-1.87459025e-04 -3.37241873e-05 -9.61712460e-06  1.39690146e-05
#   1.31150874e-04]
#   subject: s05, gcPC0, q=3, n_bursts=500
#  bins: [-1.81927567e-04 -2.34465386e-05 -7.45602333e-07  2.25612948e-05
#   1.45563261e-04]
#   subject: s05, gcPC1, q=3, n_bursts=500
#  bins: [-9.37331533e-05 -1.17052934e-05  2.12335152e-06  1.67467400e-05
#   9.60046327e-05]
#   subject: s05, gcPC-2, q=3, n_bursts=500
#  bins: [-7.00321805e-05 -1.23777900e-05 -4.39404030e-07  1.02218846e-05
#   7.50548939e-05]
#   subject: s05, gcPC-1, q=3, n_bursts=500
#  bins: [-2.26037275e-04 -3.38577258e-05 -1.39666318e-06  3.61259771e-05
#   2.17480639e-04]
#   subject: s06, gcPC0, q=0, n_bursts=547
#  bins: [-1.55286790e-04 -1.76186429e-05  1.96328553e-07  1.80414959e-05
#   1.42085646e-04]
#   subject: s06, gcPC1, q=0, n_bursts=547
#  bins: [-9.76436868e-05 -1.46021707e-05 -9.14220824e-07  1.31940452e-05
#   9.08561883e-05]
#   subject: s06, gcPC-2, q=0, n_bursts=547
#  bins: [-1.70768198e-04 -3.57631907e-05 -1.42829394e-05  3.39347584e-06
#   9.29673108e-05]
#   subject: s06, gcPC-1, q=0, n_bursts=547
#  bins: [-2.26037275e-04 -3.38577258e-05 -1.39666318e-06  3.61259771e-05
#   2.17480639e-04]
#   subject: s06, gcPC0, q=1, n_bursts=547
#  bins: [-1.55286790e-04 -1.76186429e-05  1.96328553e-07  1.80414959e-05
#   1.42085646e-04]
#   subject: s06, gcPC1, q=1, n_bursts=547
#  bins: [-9.76436868e-05 -1.46021707e-05 -9.14220824e-07  1.31940452e-05
#   9.08561883e-05]
#   subject: s06, gcPC-2, q=1, n_bursts=547
#  bins: [-1.70768198e-04 -3.57631907e-05 -1.42829394e-05  3.39347584e-06
#   9.29673108e-05]
#   subject: s06, gcPC-1, q=1, n_bursts=547
#  bins: [-2.26037275e-04 -3.38577258e-05 -1.39666318e-06  3.61259771e-05
#   2.17480639e-04]
#   subject: s06, gcPC0, q=2, n_bursts=547
#  bins: [-1.55286790e-04 -1.76186429e-05  1.96328553e-07  1.80414959e-05
#   1.42085646e-04]
#   subject: s06, gcPC1, q=2, n_bursts=547
#  bins: [-9.76436868e-05 -1.46021707e-05 -9.14220824e-07  1.31940452e-05
#   9.08561883e-05]
#   subject: s06, gcPC-2, q=2, n_bursts=547
#  bins: [-1.70768198e-04 -3.57631907e-05 -1.42829394e-05  3.39347584e-06
#   9.29673108e-05]
#   subject: s06, gcPC-1, q=2, n_bursts=547
#  bins: [-2.26037275e-04 -3.38577258e-05 -1.39666318e-06  3.61259771e-05
#   2.17480639e-04]
#   subject: s06, gcPC0, q=3, n_bursts=548
#  bins: [-1.55286790e-04 -1.76186429e-05  1.96328553e-07  1.80414959e-05
#   1.42085646e-04]
#   subject: s06, gcPC1, q=3, n_bursts=548
#  bins: [-9.76436868e-05 -1.46021707e-05 -9.14220824e-07  1.31940452e-05
#   9.08561883e-05]
#   subject: s06, gcPC-2, q=3, n_bursts=548
#  bins: [-1.70768198e-04 -3.57631907e-05 -1.42829394e-05  3.39347584e-06
#   9.29673108e-05]
#   subject: s06, gcPC-1, q=3, n_bursts=548
#  bins: [-7.57237219e-05 -1.52263037e-05  1.86505593e-06  1.78909649e-05
#   9.00258488e-05]
#   subject: s07, gcPC0, q=0, n_bursts=489
#  bins: [-1.32872408e-04 -2.84613757e-05 -1.30393250e-06  2.65610104e-05
#   1.41361915e-04]
#   subject: s07, gcPC1, q=0, n_bursts=489
#  bins: [-5.32649965e-05 -7.03268063e-06  1.07723495e-06  8.47912130e-06
#   4.57093042e-05]
#   subject: s07, gcPC-2, q=0, n_bursts=489
#  bins: [-6.33021794e-05 -1.06442959e-05 -1.99922100e-08  1.05037494e-05
#   6.48870794e-05]
#   subject: s07, gcPC-1, q=0, n_bursts=489
#  bins: [-7.57237219e-05 -1.52263037e-05  1.86505593e-06  1.78909649e-05
#   9.00258488e-05]
#   subject: s07, gcPC0, q=1, n_bursts=488
#  bins: [-1.32872408e-04 -2.84613757e-05 -1.30393250e-06  2.65610104e-05
#   1.41361915e-04]
#   subject: s07, gcPC1, q=1, n_bursts=488
#  bins: [-5.32649965e-05 -7.03268063e-06  1.07723495e-06  8.47912130e-06
#   4.57093042e-05]
#   subject: s07, gcPC-2, q=1, n_bursts=488
#  bins: [-6.33021794e-05 -1.06442959e-05 -1.99922100e-08  1.05037494e-05
#   6.48870794e-05]
#   subject: s07, gcPC-1, q=1, n_bursts=488
#  bins: [-7.57237219e-05 -1.52263037e-05  1.86505593e-06  1.78909649e-05
#   9.00258488e-05]
#   subject: s07, gcPC0, q=2, n_bursts=489
#  bins: [-1.32872408e-04 -2.84613757e-05 -1.30393250e-06  2.65610104e-05
#   1.41361915e-04]
#   subject: s07, gcPC1, q=2, n_bursts=489
#  bins: [-5.32649965e-05 -7.03268063e-06  1.07723495e-06  8.47912130e-06
#   4.57093042e-05]
#   subject: s07, gcPC-2, q=2, n_bursts=489
#  bins: [-6.33021794e-05 -1.06442959e-05 -1.99922100e-08  1.05037494e-05
#   6.48870794e-05]
#   subject: s07, gcPC-1, q=2, n_bursts=489
#  bins: [-7.57237219e-05 -1.52263037e-05  1.86505593e-06  1.78909649e-05
#   9.00258488e-05]
#   subject: s07, gcPC0, q=3, n_bursts=489
#  bins: [-1.32872408e-04 -2.84613757e-05 -1.30393250e-06  2.65610104e-05
#   1.41361915e-04]
#   subject: s07, gcPC1, q=3, n_bursts=489
#  bins: [-5.32649965e-05 -7.03268063e-06  1.07723495e-06  8.47912130e-06
#   4.57093042e-05]
#   subject: s07, gcPC-2, q=3, n_bursts=489
#  bins: [-6.33021794e-05 -1.06442959e-05 -1.99922100e-08  1.05037494e-05
#   6.48870794e-05]
#   subject: s07, gcPC-1, q=3, n_bursts=489
#  bins: [-2.76012655e-04 -1.69862155e-05 -8.29383260e-07  1.44456937e-05
#   2.58288012e-04]
#   subject: s08, gcPC0, q=0, n_bursts=470
#  bins: [-2.20060808e-04 -1.27494047e-05  4.30759089e-08  1.53492087e-05
#   2.45998939e-04]
#   subject: s08, gcPC1, q=0, n_bursts=470
#  bins: [-1.00020469e-04 -1.61547875e-05 -5.56666786e-06  5.15106220e-06
#   8.81322996e-05]
#   subject: s08, gcPC-2, q=0, n_bursts=470
#  bins: [-1.60278075e-04 -2.00519473e-05 -2.92480434e-06  1.45006111e-05
#   1.48589063e-04]
#   subject: s08, gcPC-1, q=0, n_bursts=470
#  bins: [-2.76012655e-04 -1.69862155e-05 -8.29383260e-07  1.44456937e-05
#   2.58288012e-04]
#   subject: s08, gcPC0, q=1, n_bursts=469
#  bins: [-2.20060808e-04 -1.27494047e-05  4.30759089e-08  1.53492087e-05
#   2.45998939e-04]
#   subject: s08, gcPC1, q=1, n_bursts=469
#  bins: [-1.00020469e-04 -1.61547875e-05 -5.56666786e-06  5.15106220e-06
#   8.81322996e-05]
#   subject: s08, gcPC-2, q=1, n_bursts=469
#  bins: [-1.60278075e-04 -2.00519473e-05 -2.92480434e-06  1.45006111e-05
#   1.48589063e-04]
#   subject: s08, gcPC-1, q=1, n_bursts=469
#  bins: [-2.76012655e-04 -1.69862155e-05 -8.29383260e-07  1.44456937e-05
#   2.58288012e-04]
#   subject: s08, gcPC0, q=2, n_bursts=469
#  bins: [-2.20060808e-04 -1.27494047e-05  4.30759089e-08  1.53492087e-05
#   2.45998939e-04]
#   subject: s08, gcPC1, q=2, n_bursts=469
#  bins: [-1.00020469e-04 -1.61547875e-05 -5.56666786e-06  5.15106220e-06
#   8.81322996e-05]
#   subject: s08, gcPC-2, q=2, n_bursts=469
#  bins: [-1.60278075e-04 -2.00519473e-05 -2.92480434e-06  1.45006111e-05
#   1.48589063e-04]
#   subject: s08, gcPC-1, q=2, n_bursts=469
#  bins: [-2.76012655e-04 -1.69862155e-05 -8.29383260e-07  1.44456937e-05
#   2.58288012e-04]
#   subject: s08, gcPC0, q=3, n_bursts=470
#  bins: [-2.20060808e-04 -1.27494047e-05  4.30759089e-08  1.53492087e-05
#   2.45998939e-04]
#   subject: s08, gcPC1, q=3, n_bursts=470
#  bins: [-1.00020469e-04 -1.61547875e-05 -5.56666786e-06  5.15106220e-06
#   8.81322996e-05]
#   subject: s08, gcPC-2, q=3, n_bursts=470
#  bins: [-1.60278075e-04 -2.00519473e-05 -2.92480434e-06  1.45006111e-05
#   1.48589063e-04]
#   subject: s08, gcPC-1, q=3, n_bursts=470
#  bins: [-1.57309428e-04 -2.76146102e-05 -7.84834170e-06  9.74717907e-06
#   1.03033897e-04]
#   subject: s10, gcPC0, q=0, n_bursts=484
#  bins: [-1.33295795e-04 -2.24101231e-05 -5.84728025e-06  7.86847932e-06
#   7.30038190e-05]
#   subject: s10, gcPC1, q=0, n_bursts=484
#  bins: [-7.72948771e-05 -1.02852274e-05 -3.89351484e-07  9.67231453e-06
#   7.19171627e-05]
#   subject: s10, gcPC-2, q=0, n_bursts=484
#  bins: [-5.92014747e-05 -5.69838355e-06  6.77219102e-06  1.96784589e-05
#   1.07991197e-04]
#   subject: s10, gcPC-1, q=0, n_bursts=484
#  bins: [-1.57309428e-04 -2.76146102e-05 -7.84834170e-06  9.74717907e-06
#   1.03033897e-04]
#   subject: s10, gcPC0, q=1, n_bursts=483
#  bins: [-1.33295795e-04 -2.24101231e-05 -5.84728025e-06  7.86847932e-06
#   7.30038190e-05]
#   subject: s10, gcPC1, q=1, n_bursts=483
#  bins: [-7.72948771e-05 -1.02852274e-05 -3.89351484e-07  9.67231453e-06
#   7.19171627e-05]
#   subject: s10, gcPC-2, q=1, n_bursts=483
#  bins: [-5.92014747e-05 -5.69838355e-06  6.77219102e-06  1.96784589e-05
#   1.07991197e-04]
#   subject: s10, gcPC-1, q=1, n_bursts=483
#  bins: [-1.57309428e-04 -2.76146102e-05 -7.84834170e-06  9.74717907e-06
#   1.03033897e-04]
#   subject: s10, gcPC0, q=2, n_bursts=484
#  bins: [-1.33295795e-04 -2.24101231e-05 -5.84728025e-06  7.86847932e-06
#   7.30038190e-05]
#   subject: s10, gcPC1, q=2, n_bursts=484
#  bins: [-7.72948771e-05 -1.02852274e-05 -3.89351484e-07  9.67231453e-06
#   7.19171627e-05]
#   subject: s10, gcPC-2, q=2, n_bursts=484
#  bins: [-5.92014747e-05 -5.69838355e-06  6.77219102e-06  1.96784589e-05
#   1.07991197e-04]
#   subject: s10, gcPC-1, q=2, n_bursts=484
#  bins: [-1.57309428e-04 -2.76146102e-05 -7.84834170e-06  9.74717907e-06
#   1.03033897e-04]
#   subject: s10, gcPC0, q=3, n_bursts=484
#  bins: [-1.33295795e-04 -2.24101231e-05 -5.84728025e-06  7.86847932e-06
#   7.30038190e-05]
#   subject: s10, gcPC1, q=3, n_bursts=484
#  bins: [-7.72948771e-05 -1.02852274e-05 -3.89351484e-07  9.67231453e-06
#   7.19171627e-05]
#   subject: s10, gcPC-2, q=3, n_bursts=484
#  bins: [-5.92014747e-05 -5.69838355e-06  6.77219102e-06  1.96784589e-05
#   1.07991197e-04]
#   subject: s10, gcPC-1, q=3, n_bursts=484
#  bins: [-1.24071262e-04 -1.02543021e-05  9.35075893e-08  1.13621795e-05
#   1.09314139e-04]
#   subject: s15, gcPC0, q=0, n_bursts=598
#  bins: [-1.61803130e-04 -1.33522719e-05 -9.58740685e-07  1.19932855e-05
#   1.09706370e-04]
#   subject: s15, gcPC1, q=0, n_bursts=598
#  bins: [-1.71958363e-04 -2.72949774e-05  2.86649281e-07  2.73860423e-05
#   1.79544975e-04]
#   subject: s15, gcPC-2, q=0, n_bursts=598
#  bins: [-2.37763554e-04 -3.51071559e-05  4.14560082e-07  3.60802279e-05
#   2.49788892e-04]
#   subject: s15, gcPC-1, q=0, n_bursts=598
#  bins: [-1.24071262e-04 -1.02543021e-05  9.35075893e-08  1.13621795e-05
#   1.09314139e-04]
#   subject: s15, gcPC0, q=1, n_bursts=598
#  bins: [-1.61803130e-04 -1.33522719e-05 -9.58740685e-07  1.19932855e-05
#   1.09706370e-04]
#   subject: s15, gcPC1, q=1, n_bursts=598
#  bins: [-1.71958363e-04 -2.72949774e-05  2.86649281e-07  2.73860423e-05
#   1.79544975e-04]
#   subject: s15, gcPC-2, q=1, n_bursts=598
#  bins: [-2.37763554e-04 -3.51071559e-05  4.14560082e-07  3.60802279e-05
#   2.49788892e-04]
#   subject: s15, gcPC-1, q=1, n_bursts=598
#  bins: [-1.24071262e-04 -1.02543021e-05  9.35075893e-08  1.13621795e-05
#   1.09314139e-04]
#   subject: s15, gcPC0, q=2, n_bursts=598
#  bins: [-1.61803130e-04 -1.33522719e-05 -9.58740685e-07  1.19932855e-05
#   1.09706370e-04]
#   subject: s15, gcPC1, q=2, n_bursts=598
#  bins: [-1.71958363e-04 -2.72949774e-05  2.86649281e-07  2.73860423e-05
#   1.79544975e-04]
#   subject: s15, gcPC-2, q=2, n_bursts=598
#  bins: [-2.37763554e-04 -3.51071559e-05  4.14560082e-07  3.60802279e-05
#   2.49788892e-04]
#   subject: s15, gcPC-1, q=2, n_bursts=598
#  bins: [-1.24071262e-04 -1.02543021e-05  9.35075893e-08  1.13621795e-05
#   1.09314139e-04]
#   subject: s15, gcPC0, q=3, n_bursts=598
#  bins: [-1.61803130e-04 -1.33522719e-05 -9.58740685e-07  1.19932855e-05
#   1.09706370e-04]
#   subject: s15, gcPC1, q=3, n_bursts=598
#  bins: [-1.71958363e-04 -2.72949774e-05  2.86649281e-07  2.73860423e-05
#   1.79544975e-04]
#   subject: s15, gcPC-2, q=3, n_bursts=598
#  bins: [-2.37763554e-04 -3.51071559e-05  4.14560082e-07  3.60802279e-05
#   2.49788892e-04]
#   subject: s15, gcPC-1, q=3, n_bursts=598
#  bins: [-1.68732717e-04 -2.00084210e-05  2.98653986e-07  1.86854762e-05
#   1.95487006e-04]
#   subject: s16, gcPC0, q=0, n_bursts=539
#  bins: [-1.62467096e-04 -2.49063991e-05 -7.92595390e-06  7.19239908e-06
#   1.22512437e-04]
#   subject: s16, gcPC1, q=0, n_bursts=539
#  bins: [-1.08052628e-04 -1.94953104e-05 -3.92977484e-06  1.09189298e-05
#   1.07047984e-04]
#   subject: s16, gcPC-2, q=0, n_bursts=539
#  bins: [-1.05873405e-04 -1.16763157e-05  1.31500482e-06  1.45187939e-05
#   1.11450527e-04]
#   subject: s16, gcPC-1, q=0, n_bursts=539
#  bins: [-1.68732717e-04 -2.00084210e-05  2.98653986e-07  1.86854762e-05
#   1.95487006e-04]
#   subject: s16, gcPC0, q=1, n_bursts=539
#  bins: [-1.62467096e-04 -2.49063991e-05 -7.92595390e-06  7.19239908e-06
#   1.22512437e-04]
#   subject: s16, gcPC1, q=1, n_bursts=539
#  bins: [-1.08052628e-04 -1.94953104e-05 -3.92977484e-06  1.09189298e-05
#   1.07047984e-04]
#   subject: s16, gcPC-2, q=1, n_bursts=539
#  bins: [-1.05873405e-04 -1.16763157e-05  1.31500482e-06  1.45187939e-05
#   1.11450527e-04]
#   subject: s16, gcPC-1, q=1, n_bursts=539
#  bins: [-1.68732717e-04 -2.00084210e-05  2.98653986e-07  1.86854762e-05
#   1.95487006e-04]
#   subject: s16, gcPC0, q=2, n_bursts=539
#  bins: [-1.62467096e-04 -2.49063991e-05 -7.92595390e-06  7.19239908e-06
#   1.22512437e-04]
#   subject: s16, gcPC1, q=2, n_bursts=539
#  bins: [-1.08052628e-04 -1.94953104e-05 -3.92977484e-06  1.09189298e-05
#   1.07047984e-04]
#   subject: s16, gcPC-2, q=2, n_bursts=539
#  bins: [-1.05873405e-04 -1.16763157e-05  1.31500482e-06  1.45187939e-05
#   1.11450527e-04]
#   subject: s16, gcPC-1, q=2, n_bursts=539
#  bins: [-1.68732717e-04 -2.00084210e-05  2.98653986e-07  1.86854762e-05
#   1.95487006e-04]
#   subject: s16, gcPC0, q=3, n_bursts=539
#  bins: [-1.62467096e-04 -2.49063991e-05 -7.92595390e-06  7.19239908e-06
#   1.22512437e-04]
#   subject: s16, gcPC1, q=3, n_bursts=539
#  bins: [-1.08052628e-04 -1.94953104e-05 -3.92977484e-06  1.09189298e-05
#   1.07047984e-04]
#   subject: s16, gcPC-2, q=3, n_bursts=539
#  bins: [-1.05873405e-04 -1.16763157e-05  1.31500482e-06  1.45187939e-05
#   1.11450527e-04]
#   subject: s16, gcPC-1, q=3, n_bursts=539
#  bins: [-1.97415894e-04 -2.27979638e-05 -2.04954402e-06  1.70867980e-05
#   2.11403103e-04]
#   subject: s17, gcPC0, q=0, n_bursts=416
#  bins: [-1.66425431e-04 -1.82663759e-05  6.97930033e-07  2.06932771e-05
#   1.75734600e-04]
#   subject: s17, gcPC1, q=0, n_bursts=416
#  bins: [-1.01015200e-03 -2.60278424e-05 -5.34329460e-07  2.49312413e-05
#   1.02554449e-03]
#   subject: s17, gcPC-2, q=0, n_bursts=416
#  bins: [-1.74168945e-03 -4.54874534e-05 -1.22642545e-06  3.87592273e-05
#   1.76493025e-03]
#   subject: s17, gcPC-1, q=0, n_bursts=416
#  bins: [-1.97415894e-04 -2.27979638e-05 -2.04954402e-06  1.70867980e-05
#   2.11403103e-04]
#   subject: s17, gcPC0, q=1, n_bursts=416
#  bins: [-1.66425431e-04 -1.82663759e-05  6.97930033e-07  2.06932771e-05
#   1.75734600e-04]
#   subject: s17, gcPC1, q=1, n_bursts=416
#  bins: [-1.01015200e-03 -2.60278424e-05 -5.34329460e-07  2.49312413e-05
#   1.02554449e-03]
#   subject: s17, gcPC-2, q=1, n_bursts=416
#  bins: [-1.74168945e-03 -4.54874534e-05 -1.22642545e-06  3.87592273e-05
#   1.76493025e-03]
#   subject: s17, gcPC-1, q=1, n_bursts=416
#  bins: [-1.97415894e-04 -2.27979638e-05 -2.04954402e-06  1.70867980e-05
#   2.11403103e-04]
#   subject: s17, gcPC0, q=2, n_bursts=416
#  bins: [-1.66425431e-04 -1.82663759e-05  6.97930033e-07  2.06932771e-05
#   1.75734600e-04]
#   subject: s17, gcPC1, q=2, n_bursts=416
#  bins: [-1.01015200e-03 -2.60278424e-05 -5.34329460e-07  2.49312413e-05
#   1.02554449e-03]
#   subject: s17, gcPC-2, q=2, n_bursts=416
#  bins: [-1.74168945e-03 -4.54874534e-05 -1.22642545e-06  3.87592273e-05
#   1.76493025e-03]
#   subject: s17, gcPC-1, q=2, n_bursts=416
#  bins: [-1.97415894e-04 -2.27979638e-05 -2.04954402e-06  1.70867980e-05
#   2.11403103e-04]
#   subject: s17, gcPC0, q=3, n_bursts=417
#  bins: [-1.66425431e-04 -1.82663759e-05  6.97930033e-07  2.06932771e-05
#   1.75734600e-04]
#   subject: s17, gcPC1, q=3, n_bursts=417
#  bins: [-1.01015200e-03 -2.60278424e-05 -5.34329460e-07  2.49312413e-05
#   1.02554449e-03]
#   subject: s17, gcPC-2, q=3, n_bursts=417
#  bins: [-1.74168945e-03 -4.54874534e-05 -1.22642545e-06  3.87592273e-05
#   1.76493025e-03]
#   subject: s17, gcPC-1, q=3, n_bursts=417
#  bins: [-1.18038581e-03 -6.28833972e-05 -1.24098257e-05  2.70897719e-05
#   6.65992280e-04]
#   subject: s18, gcPC0, q=0, n_bursts=452
#  bins: [-9.40041642e-04 -4.14601554e-05 -1.80359718e-06  3.40763133e-05
#   5.02680122e-04]
#   subject: s18, gcPC1, q=0, n_bursts=452
#  bins: [-8.48441271e-04 -3.67194990e-05  8.33008947e-07  4.21923519e-05
#   9.28776434e-04]
#   subject: s18, gcPC-2, q=0, n_bursts=452
#  bins: [-1.73585748e-03 -6.18214116e-05  5.31094658e-06  8.17578319e-05
#   1.79313606e-03]
#   subject: s18, gcPC-1, q=0, n_bursts=452
#  bins: [-1.18038581e-03 -6.28833972e-05 -1.24098257e-05  2.70897719e-05
#   6.65992280e-04]
#   subject: s18, gcPC0, q=1, n_bursts=451
#  bins: [-9.40041642e-04 -4.14601554e-05 -1.80359718e-06  3.40763133e-05
#   5.02680122e-04]
#   subject: s18, gcPC1, q=1, n_bursts=451
#  bins: [-8.48441271e-04 -3.67194990e-05  8.33008947e-07  4.21923519e-05
#   9.28776434e-04]
#   subject: s18, gcPC-2, q=1, n_bursts=451
#  bins: [-1.73585748e-03 -6.18214116e-05  5.31094658e-06  8.17578319e-05
#   1.79313606e-03]
#   subject: s18, gcPC-1, q=1, n_bursts=451
#  bins: [-1.18038581e-03 -6.28833972e-05 -1.24098257e-05  2.70897719e-05
#   6.65992280e-04]
#   subject: s18, gcPC0, q=2, n_bursts=452
#  bins: [-9.40041642e-04 -4.14601554e-05 -1.80359718e-06  3.40763133e-05
#   5.02680122e-04]
#   subject: s18, gcPC1, q=2, n_bursts=452
#  bins: [-8.48441271e-04 -3.67194990e-05  8.33008947e-07  4.21923519e-05
#   9.28776434e-04]
#   subject: s18, gcPC-2, q=2, n_bursts=452
#  bins: [-1.73585748e-03 -6.18214116e-05  5.31094658e-06  8.17578319e-05
#   1.79313606e-03]
#   subject: s18, gcPC-1, q=2, n_bursts=452
#  bins: [-1.18038581e-03 -6.28833972e-05 -1.24098257e-05  2.70897719e-05
#   6.65992280e-04]
#   subject: s18, gcPC0, q=3, n_bursts=452
#  bins: [-9.40041642e-04 -4.14601554e-05 -1.80359718e-06  3.40763133e-05
#   5.02680122e-04]
#   subject: s18, gcPC1, q=3, n_bursts=452
#  bins: [-8.48441271e-04 -3.67194990e-05  8.33008947e-07  4.21923519e-05
#   9.28776434e-04]
#   subject: s18, gcPC-2, q=3, n_bursts=452
#  bins: [-1.73585748e-03 -6.18214116e-05  5.31094658e-06  8.17578319e-05
#   1.79313606e-03]
#   subject: s18, gcPC-1, q=3, n_bursts=452

# %%
# Plot coefficients for each fold and for s18 
#(s18 being the test subject left out in the fold where it is the test subject,
# and included in the train set for every other fold)

for key, j in subjects_coefs.items():
    if key != 's18':
        mean_train_coefs = np.mean(subjects_coefs[key], axis=0)

plt.plot(mean_train_coefs[0],  linestyle='-.', color='black', label='LOOCV')  # linestyle='-', 
plt.plot(subjects_coefs['s18'][0].flatten(), color='red', alpha=0.3, label='Left=s18')
plt.legend()
plt.title('Logistic Regression Coefficients')
plt.xlabel('Feature Index')
plt.ylabel('Coefficient Value')
plt.show()

# %%
# Plot mean burst count as a function of features (gcPCs and percentiles) for Train vs Test (with SEM)

for key, j in subjects_bursts.items():
    if key != 's18':
        mean_train_bursts = np.mean(subjects_bursts[key], axis=0)
        std_train_bursts = np.std(subjects_bursts[key], axis=0)

upper = mean_train_bursts + np.sqrt(std_train_bursts)
lower = mean_train_bursts - np.sqrt(std_train_bursts)

y_lim = max(int(np.max(upper)), int(np.max(np.mean(subjects_bursts['s18'], axis=0))))
print(y_lim)

plt.plot(mean_train_bursts, color='black', label='Train')
plt.plot(upper, color='purple', alpha=0.2)
plt.plot(lower, color='purple', alpha=0.2)
plt.fill_between(range(len(mean_train_bursts)), lower, upper, color='purple', alpha=0.1)
plt.plot(np.mean(subjects_bursts['s18'], axis=0), color='red', label='Test')

for j, col in zip(range(0, len(np.mean(subjects_bursts['s18'], axis=0)), 4), cols):
    plt.axvline(j, color='black', linestyle='--', alpha=0.5, label="#gcPCs" if j == 0 else None)
    plt.text(j+0.2, y_lim+6*(y_lim/100), f" gcPC{col}")

for j in range(0, len(np.mean(subjects_bursts['s18'], axis=0))):
    plt.axvline(j, color='gray', linestyle='--', alpha=0.3, label="#bins" if j == 0 else None)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylabel("Burst count"), plt.xlabel("Features"), plt.title("Group-level - f(Features) = Burst Count")
# Out:
# 4
# (Text(0, 0.5, 'Burst count'),
#  Text(0.5, 0, 'Features'),
#  Text(0.5, 1.0, 'Group-level - f(Features) = Burst Count'))

# %%
area = stn_idx

# Scale waveforms within subject such as (X - median)/IQR 
scaled_waveforms = np.zeros_like(correct_bursts['waveform'])

n_q = 4
col_r = plt.cm.cool(np.linspace(0, 1, num=n_q))
rev_col_r = col_r[::-1]
step = 100 / n_q

gcPC = [0, 1, -2, -1]

fig, ax = plt.subplots(len(gcPC), n_q, figsize=(4*n_q, len(gcPC)*4), constrained_layout=True)

labels = []
q_waveforms = []
subjects_scores = []
for subject in np.unique(correct_bursts['subject']):
    subj_idx = (correct_bursts['subject'] == subject)
    # scaler = RobustScaler().fit(correct_bursts['waveform'][subj_idx & area])          # .fit() returns the median and IQR values
    # scaler = StandardScaler().fit(correct_bursts['waveform'][subj_idx & area])        # .fit() returns the mean and std values
    median, mad = scaler_fit(correct_bursts['waveform'][subj_idx & area])               # .fit() returns the median and IQR values
    subj_med = correct_bursts['med'][subj_idx & area]
    subj_bursts = correct_bursts['waveform'][subj_idx & area,:]
    subj_on_idx = (subj_med=='ON')
    subj_off_idx = (subj_med=='OFF')
    # subj_scaled_waveforms = scaler.transform(subj_bursts)
    subj_scaled_waveforms = scaler_transform(subj_bursts, median, mad)

    sub_gcpca_model = gcPCA(method='v4', normalize_flag=False)
    sub_gcpca_model.fit(subj_scaled_waveforms[subj_on_idx,:], subj_scaled_waveforms[subj_off_idx,:])
    subj_scores = subj_scaled_waveforms @ sub_gcpca_model.loadings_
    subjects_scores.append(subj_scores)

    for q in range(n_q):
        for col in gcPC:
            q_bins = np.percentile(subj_scores[:, col], np.arange(0, 100+step, step))
            print(" bins:", q_bins)

            if q==(n_q-1):
                lims = (subj_scores[:, col] >= q_bins[q])
            else:
                lims = (subj_scores[:, col] >= q_bins[q]) & (subj_scores[:, col] < q_bins[q+1])
            print(f'  subject: {subject}, gcPC{col}, q={q}, n_bursts={len(np.where(lims)[0])}')
            q_waveform = np.mean(subj_scaled_waveforms[lims, :], axis=0)
            q_waveforms.append(q_waveform)

            if len(np.where(lims)[0]) > 0:
                label = f'{subject}'
            else:
                label = None

            if label not in labels:
                labels.append(label)

            ax[col, q].plot(burst_times, q_waveform, label=label)
            ax[len(gcPC)-1, q].set_xlabel('Burst time (ms)')
            ax[col, 0].set_ylabel(f'gcPC{col}\nAmplitude (µV)')
            ax[0, q].set_title(f"T{q+1}")
            ax[col, q].set_box_aspect(1)

            if subject == np.unique(correct_bursts['subject'])[-1]:
                ax[col, q].plot(burst_times, np.mean(q_waveforms, axis=0), color='black', linestyle='--', label='Average')

                if 'Average' not in labels:
                    labels.append('Average')

fig.suptitle('Subject-level - Burst waveforms across gcPCs and quantiles', fontsize=16)
fig.legend(labels=labels, bbox_to_anchor=(1.05, 1), loc='upper left')
# Out:
#  bins: [-9.93674556e-05 -1.13923760e-05  1.28260343e-06  1.31850534e-05
#   1.80433952e-04]
#   subject: s02, gcPC0, q=0, n_bursts=474
#  bins: [-1.88244114e-04 -2.40754085e-05 -6.72590833e-06  8.47882930e-06
#   1.34464239e-04]
#   subject: s02, gcPC1, q=0, n_bursts=474
#  bins: [-1.49249315e-04 -3.68239661e-05 -1.48869329e-06  2.94459834e-05
#   1.32607371e-04]
#   subject: s02, gcPC-2, q=0, n_bursts=474
#  bins: [-1.01979418e-04 -2.45496880e-05  1.60494837e-06  2.31117908e-05
#   8.28636485e-05]
#   subject: s02, gcPC-1, q=0, n_bursts=474
#  bins: [-9.93674556e-05 -1.13923760e-05  1.28260343e-06  1.31850534e-05
#   1.80433952e-04]
#   subject: s02, gcPC0, q=1, n_bursts=474
#  bins: [-1.88244114e-04 -2.40754085e-05 -6.72590833e-06  8.47882930e-06
#   1.34464239e-04]
#   subject: s02, gcPC1, q=1, n_bursts=474
#  bins: [-1.49249315e-04 -3.68239661e-05 -1.48869329e-06  2.94459834e-05
#   1.32607371e-04]
#   subject: s02, gcPC-2, q=1, n_bursts=474
#  bins: [-1.01979418e-04 -2.45496880e-05  1.60494837e-06  2.31117908e-05
#   8.28636485e-05]
#   subject: s02, gcPC-1, q=1, n_bursts=474
#  bins: [-9.93674556e-05 -1.13923760e-05  1.28260343e-06  1.31850534e-05
#   1.80433952e-04]
#   subject: s02, gcPC0, q=2, n_bursts=474
#  bins: [-1.88244114e-04 -2.40754085e-05 -6.72590833e-06  8.47882930e-06
#   1.34464239e-04]
#   subject: s02, gcPC1, q=2, n_bursts=474
#  bins: [-1.49249315e-04 -3.68239661e-05 -1.48869329e-06  2.94459834e-05
#   1.32607371e-04]
#   subject: s02, gcPC-2, q=2, n_bursts=474
#  bins: [-1.01979418e-04 -2.45496880e-05  1.60494837e-06  2.31117908e-05
#   8.28636485e-05]
#   subject: s02, gcPC-1, q=2, n_bursts=474
#  bins: [-9.93674556e-05 -1.13923760e-05  1.28260343e-06  1.31850534e-05
#   1.80433952e-04]
#   subject: s02, gcPC0, q=3, n_bursts=475
#  bins: [-1.88244114e-04 -2.40754085e-05 -6.72590833e-06  8.47882930e-06
#   1.34464239e-04]
#   subject: s02, gcPC1, q=3, n_bursts=475
#  bins: [-1.49249315e-04 -3.68239661e-05 -1.48869329e-06  2.94459834e-05
#   1.32607371e-04]
#   subject: s02, gcPC-2, q=3, n_bursts=475
#  bins: [-1.01979418e-04 -2.45496880e-05  1.60494837e-06  2.31117908e-05
#   8.28636485e-05]
#   subject: s02, gcPC-1, q=3, n_bursts=475
#  bins: [-7.10666902e-05 -5.00386088e-06  1.88288514e-06  8.10410821e-06
#   8.33386679e-05]
#   subject: s04, gcPC0, q=0, n_bursts=515
#  bins: [-7.53873664e-05 -4.01707632e-06  9.92705887e-07  5.98423273e-06
#   5.88750887e-05]
#   subject: s04, gcPC1, q=0, n_bursts=515
#  bins: [-2.84841494e-03 -7.60819579e-05  1.03660114e-06  1.69958449e-04
#   2.88498120e-03]
#   subject: s04, gcPC-2, q=0, n_bursts=515
#  bins: [-1.56141441e-03 -1.07057243e-04 -1.02287841e-06  3.16166034e-05
#   1.57845373e-03]
#   subject: s04, gcPC-1, q=0, n_bursts=515
#  bins: [-7.10666902e-05 -5.00386088e-06  1.88288514e-06  8.10410821e-06
#   8.33386679e-05]
#   subject: s04, gcPC0, q=1, n_bursts=514
#  bins: [-7.53873664e-05 -4.01707632e-06  9.92705887e-07  5.98423273e-06
#   5.88750887e-05]
#   subject: s04, gcPC1, q=1, n_bursts=514
#  bins: [-2.84841494e-03 -7.60819579e-05  1.03660114e-06  1.69958449e-04
#   2.88498120e-03]
#   subject: s04, gcPC-2, q=1, n_bursts=514
#  bins: [-1.56141441e-03 -1.07057243e-04 -1.02287841e-06  3.16166034e-05
#   1.57845373e-03]
#   subject: s04, gcPC-1, q=1, n_bursts=514
#  bins: [-7.10666902e-05 -5.00386088e-06  1.88288514e-06  8.10410821e-06
#   8.33386679e-05]
#   subject: s04, gcPC0, q=2, n_bursts=514
#  bins: [-7.53873664e-05 -4.01707632e-06  9.92705887e-07  5.98423273e-06
#   5.88750887e-05]
#   subject: s04, gcPC1, q=2, n_bursts=514
#  bins: [-2.84841494e-03 -7.60819579e-05  1.03660114e-06  1.69958449e-04
#   2.88498120e-03]
#   subject: s04, gcPC-2, q=2, n_bursts=514
#  bins: [-1.56141441e-03 -1.07057243e-04 -1.02287841e-06  3.16166034e-05
#   1.57845373e-03]
#   subject: s04, gcPC-1, q=2, n_bursts=514
#  bins: [-7.10666902e-05 -5.00386088e-06  1.88288514e-06  8.10410821e-06
#   8.33386679e-05]
#   subject: s04, gcPC0, q=3, n_bursts=515
#  bins: [-7.53873664e-05 -4.01707632e-06  9.92705887e-07  5.98423273e-06
#   5.88750887e-05]
#   subject: s04, gcPC1, q=3, n_bursts=515
#  bins: [-2.84841494e-03 -7.60819579e-05  1.03660114e-06  1.69958449e-04
#   2.88498120e-03]
#   subject: s04, gcPC-2, q=3, n_bursts=515
#  bins: [-1.56141441e-03 -1.07057243e-04 -1.02287841e-06  3.16166034e-05
#   1.57845373e-03]
#   subject: s04, gcPC-1, q=3, n_bursts=515
#  bins: [-1.87459025e-04 -3.37241873e-05 -9.61712460e-06  1.39690146e-05
#   1.31150874e-04]
#   subject: s05, gcPC0, q=0, n_bursts=500
#  bins: [-1.81927567e-04 -2.34465386e-05 -7.45602333e-07  2.25612948e-05
#   1.45563261e-04]
#   subject: s05, gcPC1, q=0, n_bursts=500
#  bins: [-9.37331533e-05 -1.17052934e-05  2.12335152e-06  1.67467400e-05
#   9.60046327e-05]
#   subject: s05, gcPC-2, q=0, n_bursts=500
#  bins: [-7.00321805e-05 -1.23777900e-05 -4.39404030e-07  1.02218846e-05
#   7.50548939e-05]
#   subject: s05, gcPC-1, q=0, n_bursts=500
#  bins: [-1.87459025e-04 -3.37241873e-05 -9.61712460e-06  1.39690146e-05
#   1.31150874e-04]
#   subject: s05, gcPC0, q=1, n_bursts=500
#  bins: [-1.81927567e-04 -2.34465386e-05 -7.45602333e-07  2.25612948e-05
#   1.45563261e-04]
#   subject: s05, gcPC1, q=1, n_bursts=500
#  bins: [-9.37331533e-05 -1.17052934e-05  2.12335152e-06  1.67467400e-05
#   9.60046327e-05]
#   subject: s05, gcPC-2, q=1, n_bursts=500
#  bins: [-7.00321805e-05 -1.23777900e-05 -4.39404030e-07  1.02218846e-05
#   7.50548939e-05]
#   subject: s05, gcPC-1, q=1, n_bursts=500
#  bins: [-1.87459025e-04 -3.37241873e-05 -9.61712460e-06  1.39690146e-05
#   1.31150874e-04]
#   subject: s05, gcPC0, q=2, n_bursts=500
#  bins: [-1.81927567e-04 -2.34465386e-05 -7.45602333e-07  2.25612948e-05
#   1.45563261e-04]
#   subject: s05, gcPC1, q=2, n_bursts=500
#  bins: [-9.37331533e-05 -1.17052934e-05  2.12335152e-06  1.67467400e-05
#   9.60046327e-05]
#   subject: s05, gcPC-2, q=2, n_bursts=500
#  bins: [-7.00321805e-05 -1.23777900e-05 -4.39404030e-07  1.02218846e-05
#   7.50548939e-05]
#   subject: s05, gcPC-1, q=2, n_bursts=500
#  bins: [-1.87459025e-04 -3.37241873e-05 -9.61712460e-06  1.39690146e-05
#   1.31150874e-04]
#   subject: s05, gcPC0, q=3, n_bursts=500
#  bins: [-1.81927567e-04 -2.34465386e-05 -7.45602333e-07  2.25612948e-05
#   1.45563261e-04]
#   subject: s05, gcPC1, q=3, n_bursts=500
#  bins: [-9.37331533e-05 -1.17052934e-05  2.12335152e-06  1.67467400e-05
#   9.60046327e-05]
#   subject: s05, gcPC-2, q=3, n_bursts=500
#  bins: [-7.00321805e-05 -1.23777900e-05 -4.39404030e-07  1.02218846e-05
#   7.50548939e-05]
#   subject: s05, gcPC-1, q=3, n_bursts=500
#  bins: [-2.26037275e-04 -3.38577258e-05 -1.39666318e-06  3.61259771e-05
#   2.17480639e-04]
#   subject: s06, gcPC0, q=0, n_bursts=547
#  bins: [-1.55286790e-04 -1.76186429e-05  1.96328553e-07  1.80414959e-05
#   1.42085646e-04]
#   subject: s06, gcPC1, q=0, n_bursts=547
#  bins: [-9.76436868e-05 -1.46021707e-05 -9.14220824e-07  1.31940452e-05
#   9.08561883e-05]
#   subject: s06, gcPC-2, q=0, n_bursts=547
#  bins: [-1.70768198e-04 -3.57631907e-05 -1.42829394e-05  3.39347584e-06
#   9.29673108e-05]
#   subject: s06, gcPC-1, q=0, n_bursts=547
#  bins: [-2.26037275e-04 -3.38577258e-05 -1.39666318e-06  3.61259771e-05
#   2.17480639e-04]
#   subject: s06, gcPC0, q=1, n_bursts=547
#  bins: [-1.55286790e-04 -1.76186429e-05  1.96328553e-07  1.80414959e-05
#   1.42085646e-04]
#   subject: s06, gcPC1, q=1, n_bursts=547
#  bins: [-9.76436868e-05 -1.46021707e-05 -9.14220824e-07  1.31940452e-05
#   9.08561883e-05]
#   subject: s06, gcPC-2, q=1, n_bursts=547
#  bins: [-1.70768198e-04 -3.57631907e-05 -1.42829394e-05  3.39347584e-06
#   9.29673108e-05]
#   subject: s06, gcPC-1, q=1, n_bursts=547
#  bins: [-2.26037275e-04 -3.38577258e-05 -1.39666318e-06  3.61259771e-05
#   2.17480639e-04]
#   subject: s06, gcPC0, q=2, n_bursts=547
#  bins: [-1.55286790e-04 -1.76186429e-05  1.96328553e-07  1.80414959e-05
#   1.42085646e-04]
#   subject: s06, gcPC1, q=2, n_bursts=547
#  bins: [-9.76436868e-05 -1.46021707e-05 -9.14220824e-07  1.31940452e-05
#   9.08561883e-05]
#   subject: s06, gcPC-2, q=2, n_bursts=547
#  bins: [-1.70768198e-04 -3.57631907e-05 -1.42829394e-05  3.39347584e-06
#   9.29673108e-05]
#   subject: s06, gcPC-1, q=2, n_bursts=547
#  bins: [-2.26037275e-04 -3.38577258e-05 -1.39666318e-06  3.61259771e-05
#   2.17480639e-04]
#   subject: s06, gcPC0, q=3, n_bursts=548
#  bins: [-1.55286790e-04 -1.76186429e-05  1.96328553e-07  1.80414959e-05
#   1.42085646e-04]
#   subject: s06, gcPC1, q=3, n_bursts=548
#  bins: [-9.76436868e-05 -1.46021707e-05 -9.14220824e-07  1.31940452e-05
#   9.08561883e-05]
#   subject: s06, gcPC-2, q=3, n_bursts=548
#  bins: [-1.70768198e-04 -3.57631907e-05 -1.42829394e-05  3.39347584e-06
#   9.29673108e-05]
#   subject: s06, gcPC-1, q=3, n_bursts=548
#  bins: [-7.57237219e-05 -1.52263037e-05  1.86505593e-06  1.78909649e-05
#   9.00258488e-05]
#   subject: s07, gcPC0, q=0, n_bursts=489
#  bins: [-1.32872408e-04 -2.84613757e-05 -1.30393250e-06  2.65610104e-05
#   1.41361915e-04]
#   subject: s07, gcPC1, q=0, n_bursts=489
#  bins: [-5.32649965e-05 -7.03268063e-06  1.07723495e-06  8.47912130e-06
#   4.57093042e-05]
#   subject: s07, gcPC-2, q=0, n_bursts=489
#  bins: [-6.33021794e-05 -1.06442959e-05 -1.99922100e-08  1.05037494e-05
#   6.48870794e-05]
#   subject: s07, gcPC-1, q=0, n_bursts=489
#  bins: [-7.57237219e-05 -1.52263037e-05  1.86505593e-06  1.78909649e-05
#   9.00258488e-05]
#   subject: s07, gcPC0, q=1, n_bursts=488
#  bins: [-1.32872408e-04 -2.84613757e-05 -1.30393250e-06  2.65610104e-05
#   1.41361915e-04]
#   subject: s07, gcPC1, q=1, n_bursts=488
#  bins: [-5.32649965e-05 -7.03268063e-06  1.07723495e-06  8.47912130e-06
#   4.57093042e-05]
#   subject: s07, gcPC-2, q=1, n_bursts=488
#  bins: [-6.33021794e-05 -1.06442959e-05 -1.99922100e-08  1.05037494e-05
#   6.48870794e-05]
#   subject: s07, gcPC-1, q=1, n_bursts=488
#  bins: [-7.57237219e-05 -1.52263037e-05  1.86505593e-06  1.78909649e-05
#   9.00258488e-05]
#   subject: s07, gcPC0, q=2, n_bursts=489
#  bins: [-1.32872408e-04 -2.84613757e-05 -1.30393250e-06  2.65610104e-05
#   1.41361915e-04]
#   subject: s07, gcPC1, q=2, n_bursts=489
#  bins: [-5.32649965e-05 -7.03268063e-06  1.07723495e-06  8.47912130e-06
#   4.57093042e-05]
#   subject: s07, gcPC-2, q=2, n_bursts=489
#  bins: [-6.33021794e-05 -1.06442959e-05 -1.99922100e-08  1.05037494e-05
#   6.48870794e-05]
#   subject: s07, gcPC-1, q=2, n_bursts=489
#  bins: [-7.57237219e-05 -1.52263037e-05  1.86505593e-06  1.78909649e-05
#   9.00258488e-05]
#   subject: s07, gcPC0, q=3, n_bursts=489
#  bins: [-1.32872408e-04 -2.84613757e-05 -1.30393250e-06  2.65610104e-05
#   1.41361915e-04]
#   subject: s07, gcPC1, q=3, n_bursts=489
#  bins: [-5.32649965e-05 -7.03268063e-06  1.07723495e-06  8.47912130e-06
#   4.57093042e-05]
#   subject: s07, gcPC-2, q=3, n_bursts=489
#  bins: [-6.33021794e-05 -1.06442959e-05 -1.99922100e-08  1.05037494e-05
#   6.48870794e-05]
#   subject: s07, gcPC-1, q=3, n_bursts=489
#  bins: [-2.76012655e-04 -1.69862155e-05 -8.29383260e-07  1.44456937e-05
#   2.58288012e-04]
#   subject: s08, gcPC0, q=0, n_bursts=470
#  bins: [-2.20060808e-04 -1.27494047e-05  4.30759089e-08  1.53492087e-05
#   2.45998939e-04]
#   subject: s08, gcPC1, q=0, n_bursts=470
#  bins: [-1.00020469e-04 -1.61547875e-05 -5.56666786e-06  5.15106220e-06
#   8.81322996e-05]
#   subject: s08, gcPC-2, q=0, n_bursts=470
#  bins: [-1.60278075e-04 -2.00519473e-05 -2.92480434e-06  1.45006111e-05
#   1.48589063e-04]
#   subject: s08, gcPC-1, q=0, n_bursts=470
#  bins: [-2.76012655e-04 -1.69862155e-05 -8.29383260e-07  1.44456937e-05
#   2.58288012e-04]
#   subject: s08, gcPC0, q=1, n_bursts=469
#  bins: [-2.20060808e-04 -1.27494047e-05  4.30759089e-08  1.53492087e-05
#   2.45998939e-04]
#   subject: s08, gcPC1, q=1, n_bursts=469
#  bins: [-1.00020469e-04 -1.61547875e-05 -5.56666786e-06  5.15106220e-06
#   8.81322996e-05]
#   subject: s08, gcPC-2, q=1, n_bursts=469
#  bins: [-1.60278075e-04 -2.00519473e-05 -2.92480434e-06  1.45006111e-05
#   1.48589063e-04]
#   subject: s08, gcPC-1, q=1, n_bursts=469
#  bins: [-2.76012655e-04 -1.69862155e-05 -8.29383260e-07  1.44456937e-05
#   2.58288012e-04]
#   subject: s08, gcPC0, q=2, n_bursts=469
#  bins: [-2.20060808e-04 -1.27494047e-05  4.30759089e-08  1.53492087e-05
#   2.45998939e-04]
#   subject: s08, gcPC1, q=2, n_bursts=469
#  bins: [-1.00020469e-04 -1.61547875e-05 -5.56666786e-06  5.15106220e-06
#   8.81322996e-05]
#   subject: s08, gcPC-2, q=2, n_bursts=469
#  bins: [-1.60278075e-04 -2.00519473e-05 -2.92480434e-06  1.45006111e-05
#   1.48589063e-04]
#   subject: s08, gcPC-1, q=2, n_bursts=469
#  bins: [-2.76012655e-04 -1.69862155e-05 -8.29383260e-07  1.44456937e-05
#   2.58288012e-04]
#   subject: s08, gcPC0, q=3, n_bursts=470
#  bins: [-2.20060808e-04 -1.27494047e-05  4.30759089e-08  1.53492087e-05
#   2.45998939e-04]
#   subject: s08, gcPC1, q=3, n_bursts=470
#  bins: [-1.00020469e-04 -1.61547875e-05 -5.56666786e-06  5.15106220e-06
#   8.81322996e-05]
#   subject: s08, gcPC-2, q=3, n_bursts=470
#  bins: [-1.60278075e-04 -2.00519473e-05 -2.92480434e-06  1.45006111e-05
#   1.48589063e-04]
#   subject: s08, gcPC-1, q=3, n_bursts=470
#  bins: [-1.57309428e-04 -2.76146102e-05 -7.84834170e-06  9.74717907e-06
#   1.03033897e-04]
#   subject: s10, gcPC0, q=0, n_bursts=484
#  bins: [-1.33295795e-04 -2.24101231e-05 -5.84728025e-06  7.86847932e-06
#   7.30038190e-05]
#   subject: s10, gcPC1, q=0, n_bursts=484
#  bins: [-7.72948771e-05 -1.02852274e-05 -3.89351484e-07  9.67231453e-06
#   7.19171627e-05]
#   subject: s10, gcPC-2, q=0, n_bursts=484
#  bins: [-5.92014747e-05 -5.69838355e-06  6.77219102e-06  1.96784589e-05
#   1.07991197e-04]
#   subject: s10, gcPC-1, q=0, n_bursts=484
#  bins: [-1.57309428e-04 -2.76146102e-05 -7.84834170e-06  9.74717907e-06
#   1.03033897e-04]
#   subject: s10, gcPC0, q=1, n_bursts=483
#  bins: [-1.33295795e-04 -2.24101231e-05 -5.84728025e-06  7.86847932e-06
#   7.30038190e-05]
#   subject: s10, gcPC1, q=1, n_bursts=483
#  bins: [-7.72948771e-05 -1.02852274e-05 -3.89351484e-07  9.67231453e-06
#   7.19171627e-05]
#   subject: s10, gcPC-2, q=1, n_bursts=483
#  bins: [-5.92014747e-05 -5.69838355e-06  6.77219102e-06  1.96784589e-05
#   1.07991197e-04]
#   subject: s10, gcPC-1, q=1, n_bursts=483
#  bins: [-1.57309428e-04 -2.76146102e-05 -7.84834170e-06  9.74717907e-06
#   1.03033897e-04]
#   subject: s10, gcPC0, q=2, n_bursts=484
#  bins: [-1.33295795e-04 -2.24101231e-05 -5.84728025e-06  7.86847932e-06
#   7.30038190e-05]
#   subject: s10, gcPC1, q=2, n_bursts=484
#  bins: [-7.72948771e-05 -1.02852274e-05 -3.89351484e-07  9.67231453e-06
#   7.19171627e-05]
#   subject: s10, gcPC-2, q=2, n_bursts=484
#  bins: [-5.92014747e-05 -5.69838355e-06  6.77219102e-06  1.96784589e-05
#   1.07991197e-04]
#   subject: s10, gcPC-1, q=2, n_bursts=484
#  bins: [-1.57309428e-04 -2.76146102e-05 -7.84834170e-06  9.74717907e-06
#   1.03033897e-04]
#   subject: s10, gcPC0, q=3, n_bursts=484
#  bins: [-1.33295795e-04 -2.24101231e-05 -5.84728025e-06  7.86847932e-06
#   7.30038190e-05]
#   subject: s10, gcPC1, q=3, n_bursts=484
#  bins: [-7.72948771e-05 -1.02852274e-05 -3.89351484e-07  9.67231453e-06
#   7.19171627e-05]
#   subject: s10, gcPC-2, q=3, n_bursts=484
#  bins: [-5.92014747e-05 -5.69838355e-06  6.77219102e-06  1.96784589e-05
#   1.07991197e-04]
#   subject: s10, gcPC-1, q=3, n_bursts=484
#  bins: [-1.24071262e-04 -1.02543021e-05  9.35075893e-08  1.13621795e-05
#   1.09314139e-04]
#   subject: s15, gcPC0, q=0, n_bursts=598
#  bins: [-1.61803130e-04 -1.33522719e-05 -9.58740685e-07  1.19932855e-05
#   1.09706370e-04]
#   subject: s15, gcPC1, q=0, n_bursts=598
#  bins: [-1.71958363e-04 -2.72949774e-05  2.86649281e-07  2.73860423e-05
#   1.79544975e-04]
#   subject: s15, gcPC-2, q=0, n_bursts=598
#  bins: [-2.37763554e-04 -3.51071559e-05  4.14560082e-07  3.60802279e-05
#   2.49788892e-04]
#   subject: s15, gcPC-1, q=0, n_bursts=598
#  bins: [-1.24071262e-04 -1.02543021e-05  9.35075893e-08  1.13621795e-05
#   1.09314139e-04]
#   subject: s15, gcPC0, q=1, n_bursts=598
#  bins: [-1.61803130e-04 -1.33522719e-05 -9.58740685e-07  1.19932855e-05
#   1.09706370e-04]
#   subject: s15, gcPC1, q=1, n_bursts=598
#  bins: [-1.71958363e-04 -2.72949774e-05  2.86649281e-07  2.73860423e-05
#   1.79544975e-04]
#   subject: s15, gcPC-2, q=1, n_bursts=598
#  bins: [-2.37763554e-04 -3.51071559e-05  4.14560082e-07  3.60802279e-05
#   2.49788892e-04]
#   subject: s15, gcPC-1, q=1, n_bursts=598
#  bins: [-1.24071262e-04 -1.02543021e-05  9.35075893e-08  1.13621795e-05
#   1.09314139e-04]
#   subject: s15, gcPC0, q=2, n_bursts=598
#  bins: [-1.61803130e-04 -1.33522719e-05 -9.58740685e-07  1.19932855e-05
#   1.09706370e-04]
#   subject: s15, gcPC1, q=2, n_bursts=598
#  bins: [-1.71958363e-04 -2.72949774e-05  2.86649281e-07  2.73860423e-05
#   1.79544975e-04]
#   subject: s15, gcPC-2, q=2, n_bursts=598
#  bins: [-2.37763554e-04 -3.51071559e-05  4.14560082e-07  3.60802279e-05
#   2.49788892e-04]
#   subject: s15, gcPC-1, q=2, n_bursts=598
#  bins: [-1.24071262e-04 -1.02543021e-05  9.35075893e-08  1.13621795e-05
#   1.09314139e-04]
#   subject: s15, gcPC0, q=3, n_bursts=598
#  bins: [-1.61803130e-04 -1.33522719e-05 -9.58740685e-07  1.19932855e-05
#   1.09706370e-04]
#   subject: s15, gcPC1, q=3, n_bursts=598
#  bins: [-1.71958363e-04 -2.72949774e-05  2.86649281e-07  2.73860423e-05
#   1.79544975e-04]
#   subject: s15, gcPC-2, q=3, n_bursts=598
#  bins: [-2.37763554e-04 -3.51071559e-05  4.14560082e-07  3.60802279e-05
#   2.49788892e-04]
#   subject: s15, gcPC-1, q=3, n_bursts=598
#  bins: [-1.68732717e-04 -2.00084210e-05  2.98653986e-07  1.86854762e-05
#   1.95487006e-04]
#   subject: s16, gcPC0, q=0, n_bursts=539
#  bins: [-1.62467096e-04 -2.49063991e-05 -7.92595390e-06  7.19239908e-06
#   1.22512437e-04]
#   subject: s16, gcPC1, q=0, n_bursts=539
#  bins: [-1.08052628e-04 -1.94953104e-05 -3.92977484e-06  1.09189298e-05
#   1.07047984e-04]
#   subject: s16, gcPC-2, q=0, n_bursts=539
#  bins: [-1.05873405e-04 -1.16763157e-05  1.31500482e-06  1.45187939e-05
#   1.11450527e-04]
#   subject: s16, gcPC-1, q=0, n_bursts=539
#  bins: [-1.68732717e-04 -2.00084210e-05  2.98653986e-07  1.86854762e-05
#   1.95487006e-04]
#   subject: s16, gcPC0, q=1, n_bursts=539
#  bins: [-1.62467096e-04 -2.49063991e-05 -7.92595390e-06  7.19239908e-06
#   1.22512437e-04]
#   subject: s16, gcPC1, q=1, n_bursts=539
#  bins: [-1.08052628e-04 -1.94953104e-05 -3.92977484e-06  1.09189298e-05
#   1.07047984e-04]
#   subject: s16, gcPC-2, q=1, n_bursts=539
#  bins: [-1.05873405e-04 -1.16763157e-05  1.31500482e-06  1.45187939e-05
#   1.11450527e-04]
#   subject: s16, gcPC-1, q=1, n_bursts=539
#  bins: [-1.68732717e-04 -2.00084210e-05  2.98653986e-07  1.86854762e-05
#   1.95487006e-04]
#   subject: s16, gcPC0, q=2, n_bursts=539
#  bins: [-1.62467096e-04 -2.49063991e-05 -7.92595390e-06  7.19239908e-06
#   1.22512437e-04]
#   subject: s16, gcPC1, q=2, n_bursts=539
#  bins: [-1.08052628e-04 -1.94953104e-05 -3.92977484e-06  1.09189298e-05
#   1.07047984e-04]
#   subject: s16, gcPC-2, q=2, n_bursts=539
#  bins: [-1.05873405e-04 -1.16763157e-05  1.31500482e-06  1.45187939e-05
#   1.11450527e-04]
#   subject: s16, gcPC-1, q=2, n_bursts=539
#  bins: [-1.68732717e-04 -2.00084210e-05  2.98653986e-07  1.86854762e-05
#   1.95487006e-04]
#   subject: s16, gcPC0, q=3, n_bursts=539
#  bins: [-1.62467096e-04 -2.49063991e-05 -7.92595390e-06  7.19239908e-06
#   1.22512437e-04]
#   subject: s16, gcPC1, q=3, n_bursts=539
#  bins: [-1.08052628e-04 -1.94953104e-05 -3.92977484e-06  1.09189298e-05
#   1.07047984e-04]
#   subject: s16, gcPC-2, q=3, n_bursts=539
#  bins: [-1.05873405e-04 -1.16763157e-05  1.31500482e-06  1.45187939e-05
#   1.11450527e-04]
#   subject: s16, gcPC-1, q=3, n_bursts=539
#  bins: [-1.97415894e-04 -2.27979638e-05 -2.04954402e-06  1.70867980e-05
#   2.11403103e-04]
#   subject: s17, gcPC0, q=0, n_bursts=416
#  bins: [-1.66425431e-04 -1.82663759e-05  6.97930033e-07  2.06932771e-05
#   1.75734600e-04]
#   subject: s17, gcPC1, q=0, n_bursts=416
#  bins: [-1.01015200e-03 -2.60278424e-05 -5.34329460e-07  2.49312413e-05
#   1.02554449e-03]
#   subject: s17, gcPC-2, q=0, n_bursts=416
#  bins: [-1.74168945e-03 -4.54874534e-05 -1.22642545e-06  3.87592273e-05
#   1.76493025e-03]
#   subject: s17, gcPC-1, q=0, n_bursts=416
#  bins: [-1.97415894e-04 -2.27979638e-05 -2.04954402e-06  1.70867980e-05
#   2.11403103e-04]
#   subject: s17, gcPC0, q=1, n_bursts=416
#  bins: [-1.66425431e-04 -1.82663759e-05  6.97930033e-07  2.06932771e-05
#   1.75734600e-04]
#   subject: s17, gcPC1, q=1, n_bursts=416
#  bins: [-1.01015200e-03 -2.60278424e-05 -5.34329460e-07  2.49312413e-05
#   1.02554449e-03]
#   subject: s17, gcPC-2, q=1, n_bursts=416
#  bins: [-1.74168945e-03 -4.54874534e-05 -1.22642545e-06  3.87592273e-05
#   1.76493025e-03]
#   subject: s17, gcPC-1, q=1, n_bursts=416
#  bins: [-1.97415894e-04 -2.27979638e-05 -2.04954402e-06  1.70867980e-05
#   2.11403103e-04]
#   subject: s17, gcPC0, q=2, n_bursts=416
#  bins: [-1.66425431e-04 -1.82663759e-05  6.97930033e-07  2.06932771e-05
#   1.75734600e-04]
#   subject: s17, gcPC1, q=2, n_bursts=416
#  bins: [-1.01015200e-03 -2.60278424e-05 -5.34329460e-07  2.49312413e-05
#   1.02554449e-03]
#   subject: s17, gcPC-2, q=2, n_bursts=416
#  bins: [-1.74168945e-03 -4.54874534e-05 -1.22642545e-06  3.87592273e-05
#   1.76493025e-03]
#   subject: s17, gcPC-1, q=2, n_bursts=416
#  bins: [-1.97415894e-04 -2.27979638e-05 -2.04954402e-06  1.70867980e-05
#   2.11403103e-04]
#   subject: s17, gcPC0, q=3, n_bursts=417
#  bins: [-1.66425431e-04 -1.82663759e-05  6.97930033e-07  2.06932771e-05
#   1.75734600e-04]
#   subject: s17, gcPC1, q=3, n_bursts=417
#  bins: [-1.01015200e-03 -2.60278424e-05 -5.34329460e-07  2.49312413e-05
#   1.02554449e-03]
#   subject: s17, gcPC-2, q=3, n_bursts=417
#  bins: [-1.74168945e-03 -4.54874534e-05 -1.22642545e-06  3.87592273e-05
#   1.76493025e-03]
#   subject: s17, gcPC-1, q=3, n_bursts=417
#  bins: [-1.18038581e-03 -6.28833972e-05 -1.24098257e-05  2.70897719e-05
#   6.65992280e-04]
#   subject: s18, gcPC0, q=0, n_bursts=452
#  bins: [-9.40041642e-04 -4.14601554e-05 -1.80359718e-06  3.40763133e-05
#   5.02680122e-04]
#   subject: s18, gcPC1, q=0, n_bursts=452
#  bins: [-8.48441271e-04 -3.67194990e-05  8.33008947e-07  4.21923519e-05
#   9.28776434e-04]
#   subject: s18, gcPC-2, q=0, n_bursts=452
#  bins: [-1.73585748e-03 -6.18214116e-05  5.31094658e-06  8.17578319e-05
#   1.79313606e-03]
#   subject: s18, gcPC-1, q=0, n_bursts=452
#  bins: [-1.18038581e-03 -6.28833972e-05 -1.24098257e-05  2.70897719e-05
#   6.65992280e-04]
#   subject: s18, gcPC0, q=1, n_bursts=451
#  bins: [-9.40041642e-04 -4.14601554e-05 -1.80359718e-06  3.40763133e-05
#   5.02680122e-04]
#   subject: s18, gcPC1, q=1, n_bursts=451
#  bins: [-8.48441271e-04 -3.67194990e-05  8.33008947e-07  4.21923519e-05
#   9.28776434e-04]
#   subject: s18, gcPC-2, q=1, n_bursts=451
#  bins: [-1.73585748e-03 -6.18214116e-05  5.31094658e-06  8.17578319e-05
#   1.79313606e-03]
#   subject: s18, gcPC-1, q=1, n_bursts=451
#  bins: [-1.18038581e-03 -6.28833972e-05 -1.24098257e-05  2.70897719e-05
#   6.65992280e-04]
#   subject: s18, gcPC0, q=2, n_bursts=452
#  bins: [-9.40041642e-04 -4.14601554e-05 -1.80359718e-06  3.40763133e-05
#   5.02680122e-04]
#   subject: s18, gcPC1, q=2, n_bursts=452
#  bins: [-8.48441271e-04 -3.67194990e-05  8.33008947e-07  4.21923519e-05
#   9.28776434e-04]
#   subject: s18, gcPC-2, q=2, n_bursts=452
#  bins: [-1.73585748e-03 -6.18214116e-05  5.31094658e-06  8.17578319e-05
#   1.79313606e-03]
#   subject: s18, gcPC-1, q=2, n_bursts=452
#  bins: [-1.18038581e-03 -6.28833972e-05 -1.24098257e-05  2.70897719e-05
#   6.65992280e-04]
#   subject: s18, gcPC0, q=3, n_bursts=452
#  bins: [-9.40041642e-04 -4.14601554e-05 -1.80359718e-06  3.40763133e-05
#   5.02680122e-04]
#   subject: s18, gcPC1, q=3, n_bursts=452
#  bins: [-8.48441271e-04 -3.67194990e-05  8.33008947e-07  4.21923519e-05
#   9.28776434e-04]
#   subject: s18, gcPC-2, q=3, n_bursts=452
#  bins: [-1.73585748e-03 -6.18214116e-05  5.31094658e-06  8.17578319e-05
#   1.79313606e-03]
#   subject: s18, gcPC-1, q=3, n_bursts=452

# %% [markdown]
# ## Plot the distribution of peak amplitudes for ON and OFF medication at Subject-level

# %%
area = stn_idx

n_bins = 100

subjects = np.unique(correct_bursts['subject'])
sub_by_2 = len(subjects) // 2

fig, ax = plt.subplots(2, sub_by_2+1, figsize=(4*sub_by_2, 1.3*sub_by_2), constrained_layout=True)
ax = ax.flatten()

peaks_amps_on = []
peaks_amps_off = []
for i, subject in enumerate(subjects):
    subj_idx = (correct_bursts['subject'] == subject)
    idx = subj_idx & area
    keep_mask = reject_outliers(correct_bursts['peak_amp_base'][idx])
    subj_outlier_free_idx = idx.copy()
    subj_outlier_free_idx[idx] = keep_mask

    median, mad = scaler_fit(correct_bursts['waveform'][subj_outlier_free_idx & area])
    subj_med = correct_bursts['med'][subj_outlier_free_idx & area]
    subj_bursts = correct_bursts['waveform'][subj_outlier_free_idx & area,:]
    subj_on_idx = (subj_med=='ON')
    subj_off_idx = (subj_med=='OFF')

    subj_scaled_waveforms = scaler_transform(subj_bursts, median, mad)

    subj_peak_amps = correct_bursts['peak_amp_base'][subj_outlier_free_idx & area]
    subj_peak_amps_on = subj_peak_amps[subj_on_idx]
    subj_peak_amps_off = subj_peak_amps[subj_off_idx]

    peaks_amps_on.append(subj_peak_amps_on)
    peaks_amps_off.append(subj_peak_amps_off)

    ax[i].hist(subj_peak_amps_on, label='ON', alpha=0.5, density=True, bins=n_bins)
    ax[i].hist(subj_peak_amps_off, label='OFF', alpha=0.5, density=True, bins=n_bins)
    ax[i].set_title(f'{subject}')
    ax[i].legend()

    if subject == subjects[-1]:
        ax[i+1].hist(np.hstack(peaks_amps_on), label='ON', alpha=0.5, density=True, bins=n_bins)
        ax[i+1].hist(np.hstack(peaks_amps_off), label='OFF', alpha=0.5, density=True, bins=n_bins)
        ax[i+1].set_title('Average')
        ax[i+1].set_xlabel('Peak amplitude (µV)')
        ax[i+1].legend()   

    if i == 0 or i == sub_by_2+1:
        ax[i].set_ylabel('Count') 

    if i >= sub_by_2+1:
        ax[i].set_xlabel('Peak amplitude (µV)')

fig.suptitle('Subject-level - Peak amplitude distributions in STN', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Subject-level - Peak amplitude distributions in STN')
